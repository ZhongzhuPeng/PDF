# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter, HTMLConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from cStringIO import StringIO


def convert_pdf_to_txt(path, pages):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = HTMLConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = file(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()

    for i, page in enumerate(PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True)):
        interpreter.process_page(page)
        if i >= pages:
            break

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text

path = '/home/zhongzhu/Desktop/Project2/Test2/CORE.pdf'
f = open('/home/zhongzhu/Desktop/Project2/Test2/CORE_extracted0801_test', 'w')
f.write(convert_pdf_to_txt(path,100))
f.close()

# %%
import re

fp = '/home/zhongzhu/Desktop/Project2/Test2/CORE_extracted0801'
f = open(fp, 'r')
boxes = f.read().split('TEXT_BOX')
f.close()

contents = {}
ls = []
for content in boxes:
    c = content.split(';')
    if(c[0].find('left:') > 0): #if not empty
        l = c[0][c[0].find('left:')+5:c[0].find('px')]
        t = c[1][c[1].find('top:')+4:c[1].find('px')]
        w = c[2][c[2].find('width:')+6:c[2].find('px')]
        h = c[3][c[3].find('height:')+7:c[3].find('px')]
        
        text = "".join(c[4:])
        lines = text.split('\n')
        
        tempCount = 0
        for line in lines:
            if not line in contents:
                contents[line.decode('utf-8')] = []
                ls.append(line.decode('utf-8'))
                #line = line + " *"
            if re.search(r'[A-Za-z0-9,.?!]', line):
                contents[line.decode('utf-8')].append( (int(l), int(t)+tempCount, int(w), int(h)) )
            tempCount += 1
#print contents
for i, text in enumerate(contents):
    if i > 100:
        break
    print(text+ ';')
    print(contents[text])
    print(len(contents[text]))
    print('----')
# Out:
# ;
# []
# 0
# ----
# clean-up;
# [(307, 68386, 175, 158), (307, 68388, 175, 158), (307, 68391, 175, 158), (307, 79338, 175, 313)]
# 4
# ----
#  Established Column lines, Pile caps area A,B &amp C;
# [(307, 20640, 126, 9)]
# 1
# ----
# installed storm drain from manhole #34 to existing drain on ;
# [(307, 22128, 162, 211)]
# 1
# ----
#  Installing the exterior finished brick around Area A &amp B;
# [(307, 54912, 144, 36)]
# 1
# ----
# ISS- insulate pipes in area C;
# [(307, 74510, 174, 371)]
# 1
# ----
# Installing Block walls at D;
# [(307, 57871, 66, 102)]
# 1
# ----
# waterproofed at windows on south side of D &amp E and sealed jts ;
# [(307, 79350, 175, 313)]
# 1
# ----
# work on water and sewer line @ NW corner of bldg.;
# [(307, 71755, 174, 99), (307, 71756, 174, 99)]
# 2
# ----
#  Remarks: G B White Rebar delivery Area &quotD&quot;
# [(19, 36425, 191, 35)]
# 1
# ----
#   24 ;
# [(179, 5600, 10, 9)]
# 1
# ----
# Storm Drain Density testing.;
# [(307, 22134, 162, 211)]
# 1
# ----
#   221 ;
# [(178, 43476, 12, 9)]
# 1
# ----
# 01/18/2015;
# [(557, 18623, 34, 78)]
# 1
# ----
# drains.;
# [(307, 30552, 161, 166)]
# 1
# ----
# Unload cast Iron pipe &amp fittings from Southern Supply.;
# [(307, 22127, 162, 211)]
# 1
# ----
# Grade beams Area &quotA&quot.;
# [(307, 27236, 166, 115)]
# 1
# ----
# in lower area's.;
# [(307, 22485, 172, 30)]
# 1
# ----
# Testing the Welds in Area A &amp B.;
# [(307, 44903, 102, 44)]
# 1
# ----
# Chipping High Pile in Area &quotE&quot;
# [(307, 27603, 162, 94)]
# 1
# ----
# Set and Tie rebar in Area &quotB&quot;
# [(307, 34401, 123, 33)]
# 1
# ----
# 42 for 4:00pm and worked there till 6:45.;
# [(307, 83663, 206, 19)]
# 1
# ----
#  Rain Out;
# [(324, 27924, 26, 10)]
# 1
# ----
# Clearing Building pad;
# [(307, 4691, 114, 222)]
# 1
# ----
# in the pile caps in Area B.;
# [(307, 41575, 174, 65)]
# 1
# ----
# stairs @ D shenthing upper walls at D stairs install insulation in ;
# [(307, 81170, 175, 458)]
# 1
# ----
# in scuppers rock in mechanical room C2 finish framing in area C;
# [(307, 71292, 175, 203)]
# 1
# ----
#  (6:35-6:00) oversee site operations Bim meeting held sub-meeting;
# [(307, 70118, 177, 9)]
# 1
# ----
# install glass on south side of E;
# [(307, 78503, 170, 179)]
# 1
# ----
# Temporary  Poles.;
# [(285, 31350, 116, 175)]
# 1
# ----
# ran roofing up parapet walls on north side of high D;
# [(307, 79019, 169, 59)]
# 1
# ----
# Area &quotD&ampE&quot- Grade beams ;
# [(307, 31818, 148, 115)]
# 1
# ----
#  Remarks: ;
# [(20, 1364, 31, 22), (20, 2967, 31, 22), (20, 3812, 31, 22), (20, 4938, 105, 35), (20, 5622, 31, 22), (20, 6492, 31, 22), (20, 7148, 31, 22), (19, 7922, 409, 73), (20, 8845, 31, 22), (20, 10683, 206, 22), (19, 12305, 245, 109), (20, 13797, 31, 22), (20, 14612, 31, 22), (19, 18355, 252, 36), (20, 19236, 31, 22), (20, 21713, 31, 22), (20, 23305, 31, 22), (20, 24298, 174, 60), (20, 27720, 31, 10), (20, 33602, 31, 22), (20, 34457, 31, 10), (20, 38082, 145, 35), (20, 39766, 31, 22), (20, 41903, 31, 22), (20, 43497, 31, 22), (20, 45142, 31, 22), (20, 46664, 31, 22), (20, 48186, 31, 22), (20, 50233, 31, 22), (20, 52123, 31, 22), (20, 53807, 31, 22), (20, 55334, 31, 22), (20, 56792, 107, 46), (20, 59145, 31, 22), (20, 61373, 31, 22), (20, 63017, 31, 22), (20, 64676, 178, 35), (20, 66159, 31, 22), (20, 68977, 31, 10), (20, 72871, 31, 22), (19, 76342, 424, 85), (20, 79788, 31, 22)]
# 42
# ----
# Laying out in the building in Area A&ampB to start installing ;
# [(307, 43138, 149, 118)]
# 1
# ----
# 1st Floor;
# [(20, 60365, 67, 198)]
# 1
# ----
# continue layout bang duct together sea duct in cafeteria;
# [(307, 72771, 152, 62), (307, 72772, 152, 62)]
# 2
# ----
# Off loading, stocking material;
# [(307, 4703, 114, 222)]
# 1
# ----
# installing frames in courtyard @ area D;
# [(307, 67740, 169, 126), (307, 67741, 169, 126)]
# 2
# ----
# storm line in north parking lot at west end;
# [(307, 78693, 176, 121), (307, 81863, 175, 182)]
# 2
# ----
#  Plumbing Underground  Area &quotC&quot;
# [(307, 34228, 88, 62)]
# 1
# ----
#  Detailing in Area D, also hanging columns and beams in Area D.;
# [(307, 50109, 168, 59)]
# 1
# ----
#  Overcast/Cold;
# [(324, 16136, 42, 10)]
# 1
# ----
#  Est. Top of pile elevations.;
# [(307, 19056, 169, 129)]
# 1
# ----
# Installing exterior framing at N Gym Wall, Mezzanine North Wall.;
# [(307, 58599, 170, 62), (307, 58600, 170, 62), (307, 58601, 170, 62), (307, 58602, 170, 62)]
# 4
# ----
#  Gary McCaan;
# [(20, 7809, 35, 9), (20, 7824, 35, 9), (20, 8680, 35, 9), (20, 8694, 35, 9), (20, 9536, 35, 9), (20, 9593, 35, 9), (20, 9751, 35, 9), (20, 9865, 35, 9), (20, 9965, 46, 36), (20, 11206, 35, 9), (20, 11292, 35, 9), (20, 11377, 35, 9), (20, 11435, 35, 9), (20, 11592, 35, 9), (20, 12876, 35, 9), (20, 13004, 35, 9), (20, 13033, 35, 9), (20, 13176, 35, 9), (20, 13262, 35, 9), (20, 14588, 35, 9), (20, 15444, 35, 9), (20, 15530, 35, 9), (20, 15616, 35, 9), (20, 55832, 35, 9), (20, 55903, 35, 9), (20, 55975, 35, 9), (20, 56046, 35, 9), (20, 57530, 35, 9), (20, 57602, 35, 9), (20, 57673, 35, 9), (20, 60056, 35, 9), (20, 60128, 35, 9), (20, 60199, 35, 9), (20, 60271, 35, 9)]
# 34
# ----
#  16;
# [(179, 7074, 8, 49), (179, 7075, 8, 49), (179, 10389, 8, 142), (179, 10392, 8, 142), (55, 13441, 9, 12), (155, 33308, 8, 75), (155, 41509, 8, 49), (155, 65468, 8, 89), (155, 65469, 8, 89), (155, 65470, 8, 89), (179, 66044, 8, 36), (179, 66045, 8, 36), (179, 67964, 8, 22), (155, 76147, 8, 102), (177, 76144, 11, 102), (155, 78036, 8, 22), (179, 77840, 8, 36), (155, 79352, 8, 22), (155, 79583, 8, 62), (179, 79486, 8, 36), (179, 79534, 8, 36), (155, 81060, 8, 49), (155, 81220, 8, 22), (179, 82097, 8, 36), (155, 82902, 8, 62), (155, 84521, 8, 22), (155, 84577, 8, 22), (155, 84624, 8, 36), (179, 84748, 8, 49), (179, 84749, 8, 49)]
# 30
# ----
# Material Delivered: Duct Work for D3 was delivered today.;
# [(20, 64677, 178, 35)]
# 1
# ----
# west side of courtyard installed glass on west side of D;
# [(307, 81181, 175, 458)]
# 1
# ----
# 05/22/2015;
# [(557, 37989, 34, 78)]
# 1
# ----
# piping in grease trap;
# [(307, 77883, 173, 225), (307, 81023, 173, 113), (307, 81144, 175, 458), (307, 81148, 175, 458), (307, 81152, 175, 458)]
# 5
# ----
# Pile caps Area &quotE&quot;
# [(307, 30063, 175, 76)]
# 1
54914, 104, 114), (20, 54917, 104, 114), (20, 54918, 104, 114), (20, 60842, 104, 539), (20, 60843, 104, 539), (20, 60844, 104, 539), (20, 60845, 104, 539), (20, 60846, 104, 539), (20, 62523, 104, 499), (20, 62524, 104, 499), (20, 62525, 104, 499), (20, 62526, 104, 499), (20, 62527, 104, 499), (20, 64205, 97, 474), (20, 64206, 97, 474), (20, 64207, 97, 474), (20, 64208, 97, 474), (20, 64209, 97, 474), (20, 65370, 104, 251), (20, 65371, 104, 251), (20, 65372, 104, 251), (20, 65373, 104, 251), (20, 67928, 62, 194), (20, 68473, 60, 22), (20, 68508, 60, 53), (20, 68509, 60, 53), (20, 72630, 60, 36), (20, 72631, 60, 36), (20, 72720, 60, 22), (20, 76120, 60, 129), (20, 76121, 60, 129), (20, 76122, 60, 129), (20, 76123, 60, 129), (20, 76124, 60, 129), (20, 79582, 60, 115), (20, 79583, 60, 115), (20, 79584, 60, 115), (20, 79585, 60, 115), (20, 79586, 60, 115), (20, 82863, 60, 102), (20, 82864, 60, 102), (20, 82865, 60, 102), (20, 82866, 60, 102), (20, 82867, 60, 102), (20, 82976, 60, 36)]
# 136
# ----
# protection;
# [(307, 71013, 157, 33)]
# 1
# ----
#  oversee site operations;
# [(307, 67079, 61, 9)]
# 1
# ----
# Drilled 12 piles area E;
# [(307, 18180, 174, 158)]
# 1
# ----
# GRL;
# [(201, 11984, 60, 22)]
# 1
# ----
# waterproofed at walls at low roofs of D and part of south wall;
# [(307, 82713, 170, 185)]
# 1
# ----
#   65 ;
# [(155, 4917, 9, 9)]
# 1
# ----
#  Installing conduits for the transformer pad.;
# [(307, 49463, 113, 9)]
# 1
# ----
# Tuesday;
# [(557, 1784, 34, 78), (557, 26202, 34, 78), (557, 29570, 34, 78), (557, 36306, 34, 78), (557, 41358, 34, 78), (557, 56514, 34, 78), (557, 64934, 34, 78), (557, 68302, 34, 78), (557, 74196, 34, 78)]
# 9
# ----
# Installing Rough in at Gym;
# [(307, 61221, 77, 129), (307, 61222, 77, 129), (307, 61223, 77, 129), (307, 61224, 77, 129), (307, 61225, 77, 129)]
# 5
# ----
# Building the man hole on Robin Hood st, storm drain tie in.;
# [(307, 23800, 156, 121)]
# 1
# ----
# Installing Water Line;
# [(307, 66097, 53, 36), (307, 66098, 53, 36)]
# 2
# ----
# Preparing for the above ground plumbing in Area A.;
# [(307, 41507, 138, 49)]
# 1
# ----
# Material Delivered: NO Glass- truck load of glass and a truck of frames;
# [(20, 69229, 406, 35)]
# 1
# ----
# Excavator-moved the matt's for the crane.;
# [(307, 18984, 110, 57)]
# 1
# ----
#  install insulation bd on C2 flash the walls on small section of ;
# [(307, 67902, 171, 44)]
# 1
# ----
#  mainly sunny;
# [(324, 67498, 39, 10), (324, 69182, 39, 10), (324, 81812, 39, 10), (324, 82654, 39, 10)]
# 4
# ----
# 11:00 am rain out;
# [(307, 30549, 161, 166), (307, 30550, 161, 166), (307, 30555, 161, 166)]
# 3
# ----
# Installing Metasl studs and Hanging Gypsum board;
# [(307, 54124, 159, 89)]
# 1
# ----
# Visitors: Johnathan Cook from Jacobs.;
# [(19, 25005, 184, 47)]
# 1
# ----
# Grade beams and ramps in Area C.;
# [(307, 46219, 91, 36)]
# 1
# ----
# Chip down high piles.;
# [(307, 23796, 156, 121)]
# 1
# ----
# Keeping the street cleaning from track out.;
# [(307, 22960, 169, 171)]
# 1
# ----
# west end washed north elevation installed scaffolding on north ;
# [(307, 72174, 170, 188)]
# 1
# ----
# RUSH MASONRY INC;
# [(20, 62082, 70, 172), (20, 62083, 70, 172), (20, 62491, 104, 499), (20, 62492, 104, 499), (20, 62493, 104, 499), (20, 64195, 97, 474), (20, 64196, 97, 474), (20, 64197, 97, 474), (20, 64198, 97, 474), (20, 64199, 97, 474), (20, 65378, 104, 251)]
# 11
# ----
# at interior walls of D3 &amp E3 frame furdowns in B install insulation ;
# [(307, 81173, 175, 458)]
# 1
# ----
# perimeter beams Area &quotA&quot;
# [(307, 22352, 172, 116)]
# 1
# ----
#  Inspections: GSE testing the concrete for grade beams in Area &quotE&quot;
# [(20, 34705, 198, 22)]
# 1
# ----
#  CORE Construction Services, LLC;
# [(20, 16347, 85, 9), (20, 16379, 85, 9), (20, 16631, 85, 9), (20, 16653, 85, 9), (20, 17912, 85, 22), (20, 19644, 85, 9), (20, 19676, 85, 75), (20, 20451, 85, 75), (20, 21280, 104, 102), (20, 22122, 104, 89), (20, 23814, 85, 9), (20, 23835, 85, 36), (20, 24208, 85, 9), (20, 25511, 85, 62), (20, 27622, 85, 9), (20, 30542, 85, 36), (20, 30590, 85, 22), (20, 31392, 85, 22), (20, 31426, 85, 9), (20, 31448, 85, 88), (20, 33068, 85, 9), (20, 33089, 104, 141), (20, 33923, 104, 498), (20, 35607, 104, 353), (20, 37291, 104, 115), (20, 40898, 85, 49), (20, 40960, 85, 9), (20, 40981, 104, 208), (20, 42582, 97, 302), (20, 44266, 104, 301), (20, 45897, 104, 195), (20, 47408, 104, 182), (20, 49119, 104, 75), (20, 50816, 104, 474), (20, 52487, 104, 474), (20, 54118, 104, 129), (20, 57863, 97, 168), (20, 71011, 85, 22), (20, 71046, 104, 62), (20, 74531, 104, 89), (20, 77795, 85, 9), (20, 77816, 85, 9), (20, 77838, 85, 36), (20, 77886, 104, 22), (20, 81014, 85, 9), (20, 81035, 85, 9), (20, 81057, 104, 49), (20, 84096, 85, 36), (20, 84382, 104, 49)]
# 49
# ----
# Area E;
# [(20, 16740, 90, 40), (20, 19018, 97, 75), (20, 22458, 67, 35), (20, 29131, 60, 101), (20, 31918, 60, 26), (20, 33481, 97, 99), (20, 33957, 104, 498), (20, 35982, 104, 167), (20, 37667, 104, 101), (20, 41722, 104, 88), (20, 56141, 72, 232), (20, 58315, 97, 604), (20, 60824, 104, 539), (20, 65864, 88, 273)]
# 14
# ----
# Area D;
# [(177, 12085, 11, 49), (55, 20177, 9, 12), (155, 28850, 8, 115), (155, 29079, 8, 36), (155, 34136, 8, 75), (155, 37605, 8, 49), (155, 37606, 8, 49), (179, 63763, 8, 169), (179, 63764, 8, 169), (179, 63765, 8, 169), (179, 63766, 8, 169), (179, 63767, 8, 169), (177, 64181, 11, 474), (177, 64182, 11, 474), (177, 64183, 11, 474), (177, 64184, 11, 474), (177, 64200, 11, 474), (177, 64201, 11, 474), (177, 64202, 11, 474), (177, 64203, 11, 474), (177, 64204, 11, 474), (179, 67809, 8, 49), (179, 67810, 8, 49), (179, 68888, 8, 62), (179, 75220, 8, 89), (179, 79535, 8, 36), (179, 80704, 8, 49)]
# 27
# ----
#  27;
# [(55, 22703, 9, 12)]
# 1
# ----
#  26;
# [(55, 21861, 9, 12), (155, 23067, 8, 36), (155, 34137, 8, 75)]
# 3
# ----
#  21;
# [(55, 17651, 9, 12), (155, 31550, 8, 22), (179, 79487, 8, 36)]
# 3
# ----
#  20;
# [(179, 10394, 8, 142), (55, 16809, 9, 12), (155, 56137, 8, 129), (155, 56138, 8, 129), (155, 56139, 8, 129), (155, 56140, 8, 129), (155, 56283, 8, 49), (155, 56284, 8, 49), (155, 56285, 8, 49), (155, 56597, 8, 36), (155, 56598, 8, 36), (179, 68777, 8, 22), (155, 71290, 8, 75), (155, 71291, 8, 75), (155, 81310, 8, 22)]
# 15
# ----
#  23;
# [(55, 19335, 9, 12), (155, 34388, 8, 36), (155, 35912, 8, 49), (155, 79430, 8, 22)]
# 4
# ----
#  22;
# [(55, 18493, 9, 12), (155, 25692, 8, 62), (155, 30151, 8, 36), (155, 35913, 8, 49), (155, 37604, 8, 49), (155, 39424, 8, 22), (155, 41785, 8, 22), (155, 68560, 8, 36), (179, 76083, 8, 22)]
# 9
# ----
# Area &quotA &amp B&quot Forming and installing rebar in perimeter grade ;
# [(307, 23991, 162, 83)]
# 1
# ----
#  29;
# [(55, 24387, 9, 12)]
# 1
# ----

# %%
import csv
f = open('empty_table.csv', 'w')
writer = csv.writer(f)

for i, text in enumerate(ls):
    if len(contents[text]) > 30:
        print text
        writer.writerow([text, len(contents[text]), contents[text][0]])
f.close()
# Out:
#  Project:
# Location:
#  Sherwood Forest Elementary School
# 4801 Maid Marion Drive
#  Fair Working Days To Date:
# Weather Delays To Date:
# Is Today Claimed as Weather Day?
# Critical Path Work Effected?
#  Weather Condition:
# Precipitation Amount:
#  N
# N
#  Sub
# Wrkrs
# Hrs
#  2nd Tier
#  2nd
# Tier
# Hrs Work Accomplished
#  Job:
# Report #:
# Date:
# Day:
# Temp:
#  14-02-002
#  1
# High
#  Low
#  S
#  Q Sch
#  Remarks:
# Notes:
#  2
#  Tanner Broughton
#  Alisha White
#  3
#   1
#   4
#  6
#  8
#  George Caillouet
#  Subcontractor
# Phoenix Constructors LLC
#  4
# Monday
#  5
#   8
#  OS
#   3
#  7
# Gulf South Engineering &amp Testing Inc
# Berkel &amp company Contractors Inc
#  F
# F
# E
# OS
#  Bernhard Mechanical Contractors, L.L.C.
#   2
#  Phoenix Constructors LLC
#  9
#  Gary McCaan
#  10
#   6
#  11
#  Eugene Naquin
# Area A
#  12
#   10
# Area C
#   7
#   5
#  CORE Construction Services, LLC
# CORE Construction Services, LLC
#  Cordeiro LLC
# Cordeiro LLC
# Malone All Star JV, LLC
#   16
# Bernhard Mechanical Contractors, L.L.C.
#   9
# Quality Iron Fabricators Inc.
# Allied Construction, LLC
#  Quality Iron Fabricators Inc.
#  Allied Construction, LLC
# Morris Drywall Systems Inc
# CFI Insulation Inc
# Atlas-Edco Inc
#  Morris Drywall Systems Inc
# New Orleans Glass Company, Inc.
# Roofing Solutions LLC
#  Marybeth Leonard
#  Ellen Heck

# %%
from itertools import product
neighbors = {}
    
for line1, line2 in product(contents, contents):
    if(line1 != line2
       and abs(int(contents[line1][0])-int(contents[line2][0]))<30
       and abs(int(contents[line1][1])-int(contents[line2][1]))<30):
        key = line1
        value = line2
        if not key in neighbors:
            neighbors[key] = []
        neighbors[key].append(value)

# %%
import Tkinter as tk
import ttk

win = tk.Tk()
win.title("Set Pairs")   

ttk.Label(win, text="Select category:").grid(column=0, row=0)   
ttk.Label(win, text="Bind content").grid(column=2, row=0)      


def select():
    dropdown2['values'] = neighbors[category.get()]  
    dropdown2.current(0)    
    
# selecte button
action = ttk.Button(win, text="Select", command=select)
action.grid(column=1, row=1)   

pairs = {}
# 
def bind():   
    key = contents[category.get()]
    new_value = contents[content.get()]
    if not key in pairs:
        pairs[key] = set([])
    pairs[key].add(new_value)
    dropdown2.current(0) 
    

# bind button
action = ttk.Button(win, text="Bind", command=bind)
action.grid(column=3, row=1) 

# creat a drop-down list
category = tk.StringVar()
dropdown1 = ttk.Combobox(win, width=60, height=20, textvariable=category)
dropdown1['values'] = list(neighbors.keys())     
dropdown1.grid(column=0, row=1)      
#dropdown1.current(0) 

# create another drop-down list
content = tk.StringVar()
dropdown2 = ttk.Combobox(win, width=60, textvariable=content)    
dropdown2.grid(column=2, row=1)        

win.mainloop()      # window

# %%
for i in pairs:
    print i
    print pairs[i]
# Out:
# (417, 114, 16, 22)
# set([(424, 136, 76, 10)])
# (417, 106, 56, 8)
# set([(417, 113, 16, 22)])
# (319, 174, 203, 28)
# set([(319, 176, 203, 28), (319, 175, 203, 28)])

# %%
path = '/home/zhongzhu/Desktop/Project2/Test/Seattle.pdf'
f = open('/home/zhongzhu/Desktop/Project2/Test/pos_extracted2', 'w')
f.write(convert_pdf_to_txt(path,2026))
f.close()

# %% [markdown]
# # extract text and its position

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter, HTMLConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from cStringIO import StringIO


def convert_pdf_to_txt(path1, path2, num):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = HTMLConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = file(path1, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()

    for i, page in enumerate(PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True)):
        interpreter.process_page(page)
        if i >= num:
            break
    text = retstr.getvalue()
    file_name = 'page' + str(num)
    f = open(path2+file_name, 'w')
    f.write(text)
    f.close()
    #text = retstr.getvalue()
    fp.close()
    device.close()
    retstr.close()

# %%
path1 = '/home/zhongzhu/Desktop/Project2/Test/Seattle.pdf'
path2 = '/home/zhongzhu/Desktop/Project2/Test/temp/'
convert_pdf_to_txt(path1, path2, 500)

# %% [markdown]
# # record positions

# %%
import re

def record_pos(path, page):
    f = open(path2+'page'+str(page), 'r')
    boxes = f.read().split('TEXT_BOX')
    f.close()

    contents = {}
    for content in boxes:
        c = content.split(';')
        if(c[0].find('left:') > 0): #if not empty
            l = c[0][c[0].find('left:')+5:c[0].find('px')]
            t = c[1][c[1].find('top:')+4:c[1].find('px')]
            w = c[2][c[2].find('width:')+6:c[2].find('px')]
            h = c[3][c[3].find('height:')+7:c[3].find('px')]

            text = "".join(c[4:])
            lines = text.split('\n')
                
            tempCount = 0
            for line in lines:
                if re.search(r'[A-Za-z0-9,.?!]', line):
                    if not line.decode('utf-8') in contents:
                        contents[line.decode('utf-8')] = [(int(l), int(t)+tempCount, int(w), int(h))]
                    else:
                        contents[line.decode('utf-8')].append((int(l), int(t)+tempCount, int(w), int(h)))
                tempCount += 1
    return contents

# %%
contents = record_pos(path2, 0)
for pos in contents:
    print(pos)
    print(contents[pos])
# Out:
#  No preparatory or initial inspections were held today
# [(85, 462, 202, 10)]
#  No QC requirements were completed today
# [(85, 522, 167, 10)]
# Asbestos Abatement
# [(95, 642, 92, 37)]
#  No QC Punch List items were issued today
# [(85, 553, 164, 24)]
#  Page 1 of 2
# [(494, 113, 38, 10)]
#  ACTIVITY START/FINISH
# [(75, 479, 89, 10)]
# Worked
# [(508, 632, 26, 20)]
# Held demo prep meeting today with AAI.  See attached minutes of meeting.  Will start next week with demo.  They brought new
# [(95, 397, 427, 27)]
#  Hours
# [(508, 631, 26, 20)]
#  CONTRACTORS ON SITE (Report first and/or last day contractors were on site)
# [(75, 583, 276, 10)]
#  REMARKS
# [(95, 328, 59, 18)]
# DATE
# [(417, 114, 16, 22)]
#  No activities were started or finished today
# [(85, 492, 165, 10)]
#  CONTRACTORS QUALITY CONTROL REPORT (QCR)
# [(123, 110, 227, 12)]
#  (Describe QC Punch List items issued, Report QC and QA Punch List items corrected)
# [(170, 540, 290, 10)]
#  The following labor hours were Reported today:
# [(85, 628, 189, 50)]
#  DACA67-02-D-2012  0004
# [(424, 159, 89, 10)]
#  (Preparatory and initial dates held and advance notice)
# [(170, 448, 185, 10)]
# None today
# [(95, 278, 158, 18), (95, 304, 152, 18), (95, 371, 101, 18)]
#  WEATHER
# [(319, 174, 203, 28)]
# Labor Classification
# [(85, 629, 189, 50)]
#  General Comments:
# [(85, 267, 78, 10)]
#  0.0
# [(532, 654, 10, 20)]
# Weather Caused No Delay
# [(319, 175, 203, 28)]
#  DAILY CONTROL INSPECTIONS AND RESULTS
# [(95, 277, 158, 18)]
# 0.0
# [(85, 631, 189, 50), (441, 633, 36, 44), (441, 634, 36, 44), (532, 655, 10, 20)]
# Worked on shutting down water and removing refrigerators
# [(95, 236, 199, 18)]
#  LABOR HOURS
# [(75, 614, 53, 10)]
#  PROJECT
# [(75, 151, 30, 8)]
# Temperature Min 21 °F, Max 44 °F No Precipitation No Wind
# [(319, 176, 203, 28)]
#  DAILY SAFETY INSPECTIONS
# [(95, 370, 101, 18)]
#  No contractors had their first or last day on site today
# [(85, 597, 206, 10)]
#  Activities in Progress:
# [(85, 225, 86, 10)]
# Employees
# [(441, 632, 36, 44)]
#  REPORT NUMBER
# [(417, 106, 56, 8)]
# Total hours worked to date:
# [(95, 643, 92, 37)]
#  CONTRACTOR
# [(75, 174, 45, 8)]
#  D/B Replace Military Family Housing P5
# [(82, 159, 130, 10)]
# license, number was okay by Jim LaFluer.
# [(95, 398, 427, 27)]
#  PREP/INITIAL DATES
# [(75, 448, 74, 10)]
# No remarks today
# [(95, 329, 59, 18)]
#  Total
# [(417, 665, 16, 10)]
#  DAILY LOG OF CONSTRUCTION - MILITARY
# [(137, 123, 192, 12)]
# OPERATING ENGINEER
# [(85, 630, 189, 50)]
#  No equipment hours were Reported today
# [(85, 699, 162, 10)]
#  CONTRACT NUMBER
# [(417, 151, 65, 8)]
#  Total operating hours to date: 0.0
# [(95, 712, 112, 10)]
#  QUALITY CONTROL TESTING AND RESULTS
# [(95, 303, 152, 18)]
#  QA/QC PUNCH LIST
# [(75, 539, 70, 10)]
#  QC REQUIREMENTS
# [(75, 509, 70, 10)]
#  Evergreene Construction, L.C.
# [(82, 182, 102, 10)]
#  AAI
# [(95, 235, 199, 18)]
#  01 Nov 2004 - Monday
# [(424, 136, 76, 10)]
#  Employer
# [(95, 641, 92, 37)]
# No Punch List items were corrected today
# [(85, 554, 164, 24)]
#  Number of
# [(441, 631, 36, 44)]
#  Safety Inspection / Safety Meetings:
# [(85, 360, 138, 10)]
#  PREPARATORY AND/OR INITIALS HELD TODAY
# [(95, 396, 427, 27)]
#  QC NARRATIVES
# [(75, 208, 61, 10)]
#  91
# [(417, 113, 16, 22)]
#  EQUIPMENT HOURS
# [(75, 685, 70, 10)]

# %% [markdown]
# # search neighbors

# %%
from itertools import product
neighbors = {}
    
for line1, line2 in product(contents, contents):
    if(line1 != line2
       and abs(int(contents[line1][0][0])-int(contents[line2][0][0]))<30
       and abs(int(contents[line1][0][1])-int(contents[line2][0][1]))<30):
        key = line1
        value = line2
        if not key in neighbors:
            neighbors[key] = []
        neighbors[key].append(value)

# %% [markdown]
# # GUI

# %%
import Tkinter as tk
import ttk

win = tk.Tk()
win.title("Set Pairs")   

ttk.Label(win, text="Select category:").grid(column=0, row=0)   
ttk.Label(win, text="Bind content").grid(column=2, row=0)      


def select():
    dropdown2['values'] = neighbors[category.get()]  
    dropdown2.current(0)    
    
# selecte button
action = ttk.Button(win, text="Select", command=select)
action.grid(column=1, row=1)   

pairs = {}
# 
def bind():   
    #key = contents[category.get()]
    #new_value = contents[content.get()]
    
    key = category.get()
    a = contents[category.get()][0]
    b = contents[content.get()][0]
    new_value = (b[0]-a[0], b[1]-a[1], b[2]-a[2], b[3]-a[3])
    
    if not key in pairs:
        pairs[key] = set([])
    pairs[key].add(new_value)
    dropdown2.current(0) 
    

# bind button
action = ttk.Button(win, text="Bind", command=bind)
action.grid(column=3, row=1) 

# creat a drop-down list
category = tk.StringVar()
dropdown1 = ttk.Combobox(win, width=60, height=20, textvariable=category)
dropdown1['values'] = list(neighbors.keys())     
dropdown1.grid(column=0, row=1)      
#dropdown1.current(0) 

# create another drop-down list
content = tk.StringVar()
dropdown2 = ttk.Combobox(win, width=60, textvariable=content)    
dropdown2.grid(column=2, row=1)        

win.mainloop()      # window

# %%
for i in pairs:
    print i
    print pairs[i]
# Out:
# DATE
# set([(7, 22, 60, -12)])
#  WEATHER
# set([(0, 2, 0, 0), (0, 1, 0, 0)])

# %%
def find_content(content_map, content_pos):
    
    content = []
    for c in content_map:
        m = 1 #radius
        for pos in content_map[c]:
            error = abs(content_pos[0]-pos[0]) + abs(content_pos[1]-pos[1])
            #print error
            if error < m:
                content.append(c)
    #print(m)
    return content
    
data = {}
content_map = record_pos(path2, 500)
for cat1, cat2 in product(content_map, pairs):
    if cat1 == cat2:
        for pos, shift in product(content_map[cat1], pairs[cat2]):
            content_pos = (pos[0]+shift[0], pos[1]+shift[1], pos[2]+shift[2], pos[3]+shift[3])
            content = find_content(content_map, content_pos)
            if cat1 in data:
                data[cat1].append(content)
            else:
                data[cat1] = [content]

# %%
print len(data[' WEATHER'])
for i in data:
    print i
    for j in data[i]:
        print j
# Out:
# 408
# DATE
# [u' 01 Nov 2004 - Monday']
# [u' 01 Nov 2004 - Monday']
# [u' 02 Nov 2004 - Tuesday']
# [u' 02 Nov 2004 - Tuesday']
# [u' 03 Nov 2004 - Wednesday']
# [u' 03 Nov 2004 - Wednesday']
# [u' 04 Nov 2004 - Thursday']
# [u' 04 Nov 2004 - Thursday']
# [u' 05 Nov 2004 - Friday']
# [u' 05 Nov 2004 - Friday']
# [u' 06 Nov 2004 - Saturday']
# [u' 08 Nov 2004 - Monday']
# [u' 09 Nov 2004 - Tuesday']
# [u' 09 Nov 2004 - Tuesday']
# [u' 10 Nov 2004 - Wednesday']
# [u' 10 Nov 2004 - Wednesday']
# [u' 11 Nov 2004 - Thursday']
# [u' 11 Nov 2004 - Thursday']
# [u' 12 Nov 2004 - Friday']
# [u' 12 Nov 2004 - Friday']
# [u' 15 Nov 2004 - Monday']
# [u' 15 Nov 2004 - Monday']
# [u' 16 Nov 2004 - Tuesday']
# [u' 16 Nov 2004 - Tuesday']
# [u' 17 Nov 2004 - Wednesday']
# [u' 17 Nov 2004 - Wednesday']
# [u' 18 Nov 2004 - Thursday']
# [u' 18 Nov 2004 - Thursday']
# [u' 19 Nov 2004 - Friday']
# [u' 19 Nov 2004 - Friday']
# [u' 22 Nov 2004 - Monday']
# [u' 22 Nov 2004 - Monday']
# [u' 23 Nov 2004 - Tuesday']
# [u' 23 Nov 2004 - Tuesday']
# [u' 22 Jul 2005 - Friday']
# [u' 23 Jul 2005 - Saturday']
# [u' 23 Jul 2005 - Saturday']
# [u' 25 Jul 2005 - Monday']
# [u' 25 Jul 2005 - Monday']
# [u' 25 Jul 2005 - Monday']
# [u' 26 Jul 2005 - Tuesday']
# [u' 26 Jul 2005 - Tuesday']
# [u' 26 Jul 2005 - Tuesday']
# [u' 27 Jul 2005 - Wednesday']
# [u' 27 Jul 2005 - Wednesday']
# [u' 27 Jul 2005 - Wednesday']
# [u' 28 Jul 2005 - Thursday']
# [u' 28 Jul 2005 - Thursday']
# [u' 28 Jul 2005 - Thursday']
# [u' 29 Jul 2005 - Friday']
# [u' 29 Jul 2005 - Friday']
# [u' 29 Jul 2005 - Friday']
# [u' 30 Jul 2005 - Saturday']
# [u' 30 Jul 2005 - Saturday']
# [u' 01 Aug 2005 - Monday']
# [u' 01 Aug 2005 - Monday']
# [u' 01 Aug 2005 - Monday']
# [u' 02 Aug 2005 - Tuesday']
# [u' 02 Aug 2005 - Tuesday']
# [u' 02 Aug 2005 - Tuesday']
# [u' 02 Aug 2005 - Tuesday']
# [u' 03 Aug 2005 - Wednesday']
#  WEATHER
# [u'Temperature Min 21 \xb0F, Max 44 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 28 \xb0F, Max 53 \xb0F No Precipitation 29 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 39 \xb0F, Max 48 \xb0F 0.12 IN Precipitation 20 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 32 \xb0F, Max 50 \xb0F No Precipitation 14 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 33 \xb0F, Max 54 \xb0F No Precipitation 13 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 23 \xb0F, Max 39 \xb0F No Precipitation 29 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 34 \xb0F, Max 41 \xb0F 0.04 IN Precipitation 8 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 35 \xb0F, Max 46 \xb0F No Precipitation 12 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 34 \xb0F, Max 51 \xb0F 0.15 IN Precipitation 13 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 41 \xb0F, Max 49 \xb0F 0.15 IN Precipitation 9 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 42 \xb0F, Max 48 \xb0F No Precipitation 12 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 34 \xb0F, Max 55 \xb0F 21 IN Precipitation 24 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 33 \xb0F, Max 51 \xb0F No Precipitation 17 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 26 \xb0F, Max 37 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 32 \xb0F, Max 48 \xb0F No Precipitation 28 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 42 \xb0F, Max 26 \xb0F No Precipitation 29 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 37 \xb0F, Max 29 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 23 \xb0F, Max 46 \xb0F No Precipitation 20 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 35 \xb0F, Max 44 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 33 \xb0F, Max 24 \xb0F 0.15 IN Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 17 \xb0F, Max 26 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 21 \xb0F, Max 30 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 24 \xb0F, Max 28 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 24 \xb0F, Max 30 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 23 \xb0F, Max 39 \xb0F No Precipitation 29 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 32 \xb0F, Max 46 \xb0F No Precipitation 8 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 36 \xb0F, Max 46 \xb0F No Precipitation 25 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 39 \xb0F, Max 46 \xb0F 0.61 IN Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 42 \xb0F, Max 57 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 33 \xb0F, Max 42 \xb0F No Precipitation 28 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 28 \xb0F, Max 48 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 24 \xb0F, Max 46 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 26 \xb0F, Max 41 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 23 \xb0F, Max 33 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 26 \xb0F, Max 35 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 21 \xb0F, Max 35 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 24 \xb0F, Max 41 \xb0F 0.01 IN Precipitation 25 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 23 \xb0F, Max 36 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 26 \xb0F, Max 51 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 30 \xb0F, Max 50 \xb0F No Precipitation 33 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 44 \xb0F, Max 53 \xb0F 0.61 IN Precipitation 21 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 30 \xb0F, Max 46 \xb0F 0.03 IN Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 22 \xb0F, Max 32 \xb0F No Precipitation 8 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 19 \xb0F, Max 26 \xb0F 0.01 IN Precipitation 9 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 16 \xb0F, Max 27 \xb0F No Precipitation 12 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 16 \xb0F, Max 29 \xb0F No Precipitation 12 MPH Wind']
# [u'Weather Caused Non-Critical Delay']
# [u'Temperature Min 16 \xb0F, Max 29 \xb0F No Precipitation 12 MPH Wind']
# [u'Weather Caused Critical Delay']
# [u'Temperature Min 23 \xb0F, Max 39 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 24 \xb0F, Max 35 \xb0F No Precipitation 23 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 21 \xb0F, Max 37 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 17 \xb0F, Max 39 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 15 \xb0F, Max 35 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 30 \xb0F, Max 37 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 30 \xb0F, Max 46 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 28 \xb0F, Max 50 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 24 \xb0F, Max 46 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 28 \xb0F, Max 30 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 24 \xb0F, Max 32 \xb0F No Precipitation 9 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 28 \xb0F, Max 38 \xb0F No Precipitation 14 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 30 \xb0F, Max 42 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 30 \xb0F, Max 40 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 32 \xb0F, Max 50 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 24 \xb0F, Max 42 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 24 \xb0F, Max 46 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 24 \xb0F, Max 42 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 24 \xb0F, Max 46 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 26 \xb0F, Max 48 \xb0F No Precipitation 28 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 24 \xb0F, Max 44 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 21 \xb0F, Max 44 \xb0F No Precipitation 7 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 19 \xb0F, Max 44 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 19 \xb0F, Max 46 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 37 \xb0F, Max 53 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 23 \xb0F, Max 41 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 15 \xb0F, Max 37 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 26 \xb0F, Max 37 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 17 \xb0F, Max 39 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 19 \xb0F, Max 44 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 33 \xb0F, Max 50 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 33 \xb0F, Max 50 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 26 \xb0F, Max 51 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 26 \xb0F, Max 51 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 24 \xb0F, Max 53 \xb0F No Precipitation 13 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 32 \xb0F, Max 45 \xb0F No Precipitation 15 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 26 \xb0F, Max 55 \xb0F No Precipitation 12 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 33 \xb0F, Max 53 \xb0F No Precipitation 14 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 33 \xb0F, Max 55 \xb0F No Precipitation 8 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 28 \xb0F, Max 57 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 30 \xb0F, Max 68 \xb0F No Precipitation 20 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 33 \xb0F, Max 69 \xb0F No Precipitation 21 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 14 \xb0F, Max 71 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 39 \xb0F, Max 68 \xb0F No Precipitation 23 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 32 \xb0F, Max 69 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 19 \xb0F, Max 54 \xb0F No Precipitation 21 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 30 \xb0F, Max 58 \xb0F No Precipitation 15 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 30 \xb0F, Max 59 \xb0F No Precipitation 44 MPH Wind']
# [u'Weather Caused Critical Delay']
# [u'Temperature Min 26 \xb0F, Max 51 \xb0F No Precipitation 32 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 19 \xb0F, Max 53 \xb0F No Precipitation No Wind']
# [u'Weather Caused Non-Critical Delay']
# [u'Temperature Min 39 \xb0F, Max 48 \xb0F 0.06 IN Precipitation No Wind']
# [u'Weather Caused Critical Delay']
# [u'Temperature Min 39 \xb0F, Max 46 \xb0F 0.07 IN Precipitation 26 MPH Wind']
# [u'Weather Caused Critical Delay']
# [u'Temperature Min 37 \xb0F, Max 53 \xb0F 0.23 IN Precipitation 25 MPH Wind']
# [u'Weather Caused Critical Delay']
# [u'Temperature Min 40 \xb0F, Max 48 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 26 \xb0F, Max 48 \xb0F No Precipitation 30 MPH Wind']
# [u'Weather Caused Critical Delay']
# [u'Temperature Min 35 \xb0F, Max 53 \xb0F 0.09 IN Precipitation 33 MPH Wind']
# [u'Weather Caused Critical Delay']
# [u'Temperature Min 33 \xb0F, Max 48 \xb0F 0.13 IN Precipitation 37 MPH Wind']
# [u'Weather Caused Critical Delay']
# [u'Temperature Min 28 \xb0F, Max 46 \xb0F No Precipitation 31 MPH Wind']
# [u'Weather Caused Non-Critical Delay']
# [u'Temperature Min 23 \xb0F, Max 53 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 39 \xb0F, Max 62 \xb0F No Precipitation 26 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 34 \xb0F, Max 49 \xb0F 0.23 IN Precipitation 30 MPH Wind']
# [u'Weather Caused Critical Delay']
# [u'Temperature Min 29 \xb0F, Max 57 \xb0F No Precipitation 18 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 37 \xb0F, Max 75 \xb0F No Precipitation 33 MPH Wind']
# [u'Weather Caused Critical Delay']
# [u'Temperature Min 45 \xb0F, Max 72 \xb0F 0.12 IN Precipitation 38 MPH Wind']
# [u'Weather Caused Critical Delay']
# [u'Temperature Min 39 \xb0F, Max 53 \xb0F No Precipitation 35 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 35 \xb0F, Max 66 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 37 \xb0F, Max 69 \xb0F No Precipitation 23 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 26 \xb0F, Max 30 \xb0F 0.01 IN Precipitation 33 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 26 \xb0F, Max 51 \xb0F 0.01 IN Precipitation 33 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 26 \xb0F, Max 60 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 35 \xb0F, Max 53 \xb0F No Precipitation 34 MPH Wind']
# [u'Weather Caused Non-Critical Delay']
# [u'Temperature Min 35 \xb0F, Max 55 \xb0F No Precipitation 23 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 42 \xb0F, Max 48 \xb0F 0.19 IN Precipitation No Wind']
# [u'Weather Caused Critical Delay']
# [u'Temperature Min 42 \xb0F, Max 59 \xb0F 0.07 IN Precipitation No Wind']
# [u'Weather Caused Non-Critical Delay']
# [u'Temperature Min 54 \xb0F, Max 71 \xb0F No Precipitation 32 MPH Wind']
# [u'Weather Caused Critical Delay']
# [u'Temperature Min 53 \xb0F, Max 64 \xb0F 0.06 IN Precipitation 23 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 48 \xb0F, Max 64 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 44 \xb0F, Max 73 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 42 \xb0F, Max 73 \xb0F No Precipitation 29 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 42 \xb0F, Max 60 \xb0F 0.02 IN Precipitation 16 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 39 \xb0F, Max 62 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 37 \xb0F, Max 71 \xb0F No Precipitation 24 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 42 \xb0F, Max 71 \xb0F No Precipitation 21 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 46 \xb0F, Max 69 \xb0F 0.04 IN Precipitation No Wind']
# [u'Weather Caused Non-Critical Delay']
# [u'Temperature Min 53 \xb0F, Max 71 \xb0F 0.81 IN Precipitation 39 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 50 \xb0F, Max 64 \xb0F 0.01 IN Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 48 \xb0F, Max 64 \xb0F 0.19 IN Precipitation 25 MPH Wind']
# [u'Weather Caused Critical Delay']
# [u'Temperature Min 44 \xb0F, Max 59 \xb0F 0.86 IN Precipitation 23 MPH Wind']
# [u'Weather Caused Critical Delay']
# [u'Temperature Min 39 \xb0F, Max 57 \xb0F No Precipitation 29 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 46 \xb0F, Max 59 \xb0F 0.17 IN Precipitation 25 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 48 \xb0F, Max 69 \xb0F No Precipitation 28 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 44 \xb0F, Max 73 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 55 \xb0F, Max 75 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 44 \xb0F, Max 59 \xb0F 0.61 IN Precipitation No Wind']
# [u'Weather Caused Critical Delay']
# [u'Temperature Min 41 \xb0F, Max 60 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 51 \xb0F, Max 61 \xb0F 0.09 IN Precipitation 24 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 51 \xb0F, Max 61 \xb0F 0.27 IN Precipitation No Wind']
# [u'Weather Caused Non-Critical Delay']
# [u'Temperature Min 51 \xb0F, Max 69 \xb0F 0.01 IN Precipitation 29 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 57 \xb0F, Max 66 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 42 \xb0F, Max 68 \xb0F No Precipitation 24 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 56 \xb0F, Max 68 \xb0F No Precipitation 28 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 37 \xb0F, Max 71 \xb0F No Precipitation 22 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 53 \xb0F, Max 80 \xb0F No Precipitation 21 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 55 \xb0F, Max 84 \xb0F No Precipitation 22 MPH Wind']
# [u'Weather Caused No Delay']
# []
# [u'Weather Not Entered']
# [u'Temperature Min 48 \xb0F, Max 80 \xb0F 0.2 IN Precipitation 25 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 44 \xb0F, Max 64 \xb0F 0.02 IN Precipitation 28 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 37 \xb0F, Max 69 \xb0F No Precipitation 22 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 44 \xb0F, Max 73 \xb0F No Precipitation 28 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 57 \xb0F, Max 78 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 42 \xb0F, Max 64 \xb0F No Precipitation 29 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 42 \xb0F, Max 64 \xb0F 0.02 IN Precipitation 29 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 39 \xb0F, Max 62 \xb0F 0.02 IN Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 35 \xb0F, Max 75 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 41 \xb0F, Max 78 \xb0F No Precipitation 14 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 37 \xb0F, Max 78 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 73 \xb0F, Max 95 \xb0F No Precipitation 29 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 68 \xb0F, Max 82 \xb0F No Precipitation 10 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 55 \xb0F, Max 87 \xb0F No Precipitation 24 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 51 \xb0F, Max 69 \xb0F 0.14 IN Precipitation 26 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 48 \xb0F, Max 96 \xb0F No Precipitation 16 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 68 \xb0F, Max 100 \xb0F No Precipitation 26 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 55 \xb0F, Max 93 \xb0F No Precipitation 18 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 55 \xb0F, Max 87 \xb0F No Precipitation 21 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 51 \xb0F, Max 91 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 73 \xb0F, Max 87 \xb0F No Precipitation 30 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 57 \xb0F, Max 71 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 55 \xb0F, Max 75 \xb0F 0.15 IN Precipitation 26 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 48 \xb0F, Max 82 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 53 \xb0F, Max 89 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 49.5 \xb0F, Max 98 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 53.4 \xb0F, Max 95.4 \xb0F No Precipitation 11 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 58.5 \xb0F, Max 94.5 \xb0F 1.7 IN Precipitation 15 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 61.5 \xb0F, Max 93.2 \xb0F No Precipitation 14 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 60 \xb0F, Max 100 \xb0F No Precipitation 18 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 64 \xb0F, Max 73 \xb0F No Precipitation 29 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 53 \xb0F, Max 96 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 62 \xb0F, Max 107 \xb0F No Precipitation 21 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 69 \xb0F, Max 98 \xb0F No Precipitation 28 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 78 \xb0F, Max 96 \xb0F No Precipitation 17 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 57 \xb0F, Max 107 \xb0F No Precipitation 37 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 73 \xb0F, Max 100 \xb0F No Precipitation 33 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 55 \xb0F, Max 98 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 64 \xb0F, Max 102 \xb0F No Precipitation 25 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 62 \xb0F, Max 102 \xb0F No Precipitation 24 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 62 \xb0F, Max 105 \xb0F No Precipitation 20 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 80 \xb0F, Max 104 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 71 \xb0F, Max 95 \xb0F No Precipitation 20 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 64 \xb0F, Max 89 \xb0F No Precipitation 30 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 57 \xb0F, Max 89 \xb0F No Precipitation 20 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 53 \xb0F, Max 98 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 60 \xb0F, Max 100 \xb0F No Precipitation 38 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 75 \xb0F, Max 95 \xb0F 0.22 IN Precipitation 18 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 73 \xb0F, Max 96 \xb0F No Precipitation 31 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 69 \xb0F, Max 96 \xb0F 0.2 IN Precipitation 29 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 59 \xb0F, Max 91 \xb0F No Precipitation 26 MPH Wind']
# [u'Weather Caused No Delay']
# [u'Temperature Min 55 \xb0F, Max 95 \xb0F No Precipitation No Wind']
# [u'Weather Caused No Delay']

# %% [markdown]
# # test

# %%
for i in content_map:
    print i
    print content_map[i]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-415e29586be7> in <module>()
# ----> 1 for i in content_map:
#       2     print i
#       3     print content_map[i]
#
# NameError: name 'content_map' is not defined

# %%
len(data[' WEATHER'])
# Out:
# 1410

# %%
contents = record_pos(path2, 14)
for pos in contents:
    print(pos)
    print(contents[pos])
# Out:
#  Employer * * * * * *
# (95, 10799, 71, 23)
# None today * * * * * * * * * * * * * * * *
# (95, 5474, 175, 18)
#  PREP/INITIAL DATES * * * * *
# (75, 8658, 75, 10)
#  The following activity was started today:
# (85, 10613, 156, 10)
#  No contractors had their first or last day on site today * * * * * * *
# (85, 10755, 206, 10)
#  WEATHER * * * * * *
# (319, 9436, 229, 28)
#  QUALITY CONTROL INSPECTIONS AND RESULTS * * *
# (95, 7013, 168, 18)
#  DACA67-02-D-2012  0004 * * * * * * * * * * * * *
# (424, 11105, 89, 10)
# DATE * * * * *
# (417, 4324, 16, 22)
# None today * * * * * * * * * * * * *
# (95, 5330, 168, 18)
# Worked *
# (508, 2721, 26, 20)
# 0.0 * * * *
# (441, 2722, 36, 44)
#  Evergreene Construction, L.C. * * * * * * *
# (82, 11970, 102, 10)
#  LABOR HOURS * * * * * *
# (75, 9859, 53, 10)
#  LABOR HOURS
# (75, 614, 53, 10)
#  No accidents reported today * *
# (85, 4445, 109, 10)
#  CONTRACTORS ON SITE (Report first and/or last day contractors w ere on site) * * * * * *
# (75, 10741, 278, 10)
#  General Comments:
# (85, 267, 78, 10)
#  QA/QC PUNCH LIST * * * * * *
# (75, 9784, 70, 10)
# 0.0 * * * * *
# (441, 2723, 36, 44)
#  No contractors had their first or last day on site today * * * * * *
# (85, 9842, 206, 10)
# Total hours w orked to date: 0.0 * * *
# (95, 7396, 112, 37)
#  0.0 * * * * * *
# (464, 11194, 10, 20)
#  DAILY SAFETY INSPECTIONS * * * * * * *
# (95, 12167, 101, 18)
#  99 *
# (417, 11059, 16, 22)
#  Total operating hours to date: 0.0 * * * * *
# (95, 8923, 112, 10)
#  Activities in Progress: *
# (85, 1909, 86, 10)
# Employees * * * * * * *
# (441, 12446, 36, 54)
#  D/B Replace Military Family Housing P5 * * * *
# (82, 3527, 130, 10)
#  Total * * *
# (417, 5734, 16, 10)
#  CONTRACTOR CERTIFICATION *
# (71, 3242, 98, 8)
#  DAILY LOG OF CONSTRUCTION - MILITARY * * * * * * * * * * * *
# (137, 10227, 192, 12)
#  General Comments: * *
# (85, 3635, 78, 10)
#  D/B Replace Military Family Housing P5 * * * * * * *
# (82, 6053, 130, 10)
# plans and specifications, to the best of my knowledge, except as noted above. * *
# (183, 4926, 386, 33)
#  CONTRACTORS FIRST AND/OR LAST DAY ONSITE * * * * * *
# (95, 12218, 175, 18)
#  (Describe accidents) * * * * * * *
# (170, 11225, 70, 10)
# None today * * * * * * * * * * * * * * * * * * * *
# (95, 7158, 175, 18)
#  REMARKS * * *
# (95, 5380, 35, 18)
#  No QC Punch List items were issued today
# (85, 553, 164, 24)
#  Operating
# (508, 11171, 33, 20)
#  Page 1 of 2
# (494, 113, 38, 10)
#  QA/QC PUNCH LIST * * * *
# (75, 7292, 70, 10)
#  QC NARRATIVES
# (75, 208, 61, 10)
# Temperature Min 32 °F, Max 50 °F No Precipitation 14 MPH Wind
# (319, 5228, 219, 28)
#  EQUIPMENT HOURS * * *
# (75, 6071, 70, 10)
#  CONTRACT NUMBER * * * * * * * * *
# (417, 7729, 65, 8)
#  No activities were started or finished today * * * * * *
# (85, 9737, 167, 10)
#  REMARKS * * * * *
# (95, 9548, 430, 27)
# Sent email to Jim LaFluer w ith UHF radio frequencies w e w ant to use onsite
# (95, 12117, 257, 18)
#  CONTRACTOR * * * * * *
# (75, 9436, 45, 8)
# None today
# (95, 278, 158, 18)
# DATE * * * *
# (417, 3482, 16, 22)
#  CONTRACTORS QUALITY CONTROL REPORT (QCR) * * * * * * * * * * * * *
# (123, 11056, 227, 12)
# Employees * *
# (441, 4017, 36, 44)
#  ACCIDENT REPORTING * *
# (75, 4431, 82, 10)
# 0.0 * * * * * * * * * * *
# (441, 5703, 36, 44)
# Worked
# (508, 632, 26, 20)
#  Hours * * * *
# (508, 7384, 26, 20)
#  LABOR HOURS * * * * * * * *
# (75, 12427, 53, 10)
# Weather Caused No Delay * * * * * * * *
# (319, 11963, 233, 28)
#  No preparatory or initial inspections were held today * * * *
# (85, 7215, 203, 10)
#  DAILY LOG OF CONSTRUCTION - MILITARY * *
# (137, 1807, 192, 12)
# plans and specifications, to the best of my knowledge, except as noted above. * * * * * *
# (183, 9978, 386, 33)
#  CONTRACTORS QUALITY CONTROL REPORT (QCR) * * * * * * * *
# (123, 6846, 227, 12)
# No safety issues * * * *
# (95, 10484, 101, 18)
#  DATE * * * * * * *
# (508, 6645, 16, 8)
#  04 Nov 2004 - Thursday *
# (424, 6030, 82, 10)
#  PREP/INITIAL DATES * * *
# (75, 5517, 74, 10)
# None today * * * *
# (95, 2047, 152, 18)
#  QC REPRESENTATIVE'S SIGNATURE * * * * * *
# (71, 10015, 115, 8)
#  No equipment hours were Reported today * * * *
# (85, 7769, 163, 10)
#  Evergreene Construction, L.C.
# (82, 182, 102, 10)
# Total operating hours to date: 10.0
# (95, 11183, 116, 37)
# Employees * * *
# (441, 5701, 36, 44)
#  REPORT NUMBER * * *
# (417, 2632, 56, 8)
# DATE *
# (417, 956, 16, 22)
#  CONTRACTORS FIRST AND/OR LAST DAY ONSITE *
# (95, 3789, 175, 18)
# No safety issues * * *
# (95, 9600, 101, 18)
#  93 *
# (417, 4323, 16, 22)
#  No QC requirements were completed today * * * * * * * *
# (85, 12336, 169, 10)
#  DATE * * * * * * * * * * * *
# (281, 10013, 16, 8)
#  QC REQUIREMENTS * * * * *
# (75, 8719, 70, 10)
#  04 Nov 2004 - Thursday
# (424, 5188, 82, 10)
#  On behalf of the contractor, I certify that this Report is complete and correct and all equipment and * * * * *
# (183, 9134, 387, 33)
#  QC REQUIREMENTS * * * * * * * *
# (75, 12322, 70, 10)
#  The following labor hours were Reported today: * * * * * * *
# (85, 12441, 186, 10)
#  Total * * * * * * *
# (417, 11205, 16, 10)
#  DACA67-02-D-2012  0004
# (424, 159, 89, 10)
#  Standby
# (441, 11171, 27, 20)
#  QUALITY CONTROL INSPECTIONS AND RESULTS * * * *
# (95, 9497, 168, 18)
#  09 Nov 2004 - Tuesday *
# (424, 11082, 79, 10)
#  CONTRACTORS FIRST AND/OR LAST DAY ONSITE * * * * *
# (95, 10534, 175, 18)
#  QC REPRESENTATIVE'S SIGNATURE * * *
# (71, 6647, 115, 8)
#  DACA67-02-D-2012  0004 * * * * * * * * * * *
# (424, 9421, 89, 10)
#  No preparatory or initial inspections were held today * *
# (85, 3847, 203, 10)
#  QC REPRESENTATIVE'S SIGNATURE * *
# (71, 4963, 115, 8)
# Total hours w orked to date: 0.0 * * * *
# (95, 8853, 112, 37)
#  DAILY LOG OF CONSTRUCTION - MILITARY * * * * * *
# (137, 5175, 192, 12)
#  No accidents reported today * * * * *
# (85, 8953, 109, 10)
#  On behalf of the contractor, I certify that this Report is complete and correct and all equipment and
# (183, 1556, 386, 33)
#  CONTRACTOR CERTIFICATION * * * * *
# (71, 9136, 98, 8)
#  Labor Classification
# (197, 2731, 78, 23)
#  QC NARRATIVES * * * * * * *
# (75, 10312, 61, 10)
#  WEATHER * * * * * * * *
# (319, 11962, 233, 28)
#  DATE * * * *
# (281, 4961, 16, 8)
# Worked * * * * * * *
# (508, 12446, 26, 20)
# None today * * * * * * * * * * * * * * * * * * * * * * * * * *
# (95, 10509, 163, 18)
#  No labor hours were Reported today
# (85, 9873, 141, 10)
#  No QC Punch List items were issued today * * * * *
# (85, 8764, 165, 24)
#  The following labor hours were Reported today: * * * *
# (85, 7380, 186, 10)
# DATE * * * * * * * * * * *
# (417, 9376, 16, 22)
#  08 Nov 2004 - Monday
# (424, 9398, 76, 10)
# OPERATING ENGINEER * * * * *
# (197, 8852, 78, 24)
# Asbestos Abatement * * * * *
# (95, 8852, 112, 37)
#  10.0 *
# (527, 11194, 14, 20)
#  DACA67-02-D-2012  0004 * * * * * * * * *
# (424, 7737, 89, 10)
#  General Comments: * * *
# (85, 5319, 78, 10)
# DATE * *
# (417, 1798, 16, 22)
# Review ed tree preservation plan w ith COE, Base and Base Arborist.  Some trees are missing and mislabeled.  Generally okay.
# (95, 1920, 432, 44)
#  98
# (417, 9375, 16, 22)
#  99
# (417, 10217, 16, 22)
# None today * * * * * * * * * * * * * * * * *
# (95, 7014, 168, 18)
# No Punch List items were corrected today * * * * * * *
# (85, 10712, 165, 24)
#  EQUIPMENT HOURS * * * * * * *
# (75, 11154, 70, 10)
#  91
# (417, 113, 16, 22)
#  92
# (417, 1797, 16, 22)
#  93
# (417, 3481, 16, 22)
#  94
# (417, 5165, 16, 22)
#  95
# (417, 6849, 16, 22)
#  96
# (417, 8533, 16, 22)
#  QUALITY CONTROL TESTING AND RESULTS * * * * * * *
# (95, 12091, 152, 18)
#  Description
# (156, 10627, 101, 20)
#  CONTRACTORS FIRST AND/OR LAST DAY ONSITE * *
# (95, 5473, 175, 18)
# 0.0
# (85, 631, 189, 50)
#  Evergreene Construction, L.C. * * *
# (82, 5234, 102, 10)
#  General Comments: * * * * * *
# (85, 10371, 78, 10)
# Shutting dow n w ater and removing refrigerators *
# (95, 5288, 164, 18)
#  No contractors had their first or last day on site today * * *
# (85, 5666, 206, 10)
#  Hours * * * * * *
# (508, 10789, 26, 20)
# DATE
# (417, 114, 16, 22)
#  No contractors had their first or last day on site today * * * * * * * *
# (85, 12411, 206, 10)
#  Labor Classification * * * *
# (197, 8851, 78, 24)
#  CONTRACTORS QUALITY CONTROL REPORT (QCR)
# (123, 110, 227, 12)
# material used and work performed during this Reporting period are in compliance with the contract * * * *
# (183, 8293, 386, 33)
#  CONTRACTOR * * * * * * * *
# (75, 11962, 45, 8)
#  The following labor hours were Reported today: * * * * * *
# (85, 10786, 186, 10)
#  SUPERINTENDENT'S INITIALS * *
# (369, 4961, 94, 8)
#  No preparatory or initial inspections were held today * * * * * * *
# (85, 10583, 203, 10)
#  ACCIDENT REPORTING * * * * *
# (75, 8939, 83, 10)
#  PROJECT *
# (75, 993, 30, 8)
#  (Describe QC Punch List items issued, Report QC and QA Punch List items corrected) * * * *
# (170, 7293, 290, 10)
#  Hours * * * * * * *
# (508, 12445, 26, 20)
# DATE * * * * * * * * * *
# (417, 8534, 16, 22)
# Total hours w orked to date: 0.0 *
# (95, 4028, 112, 37)
# Worked * * * * * *
# (508, 10790, 26, 20)
#  LABOR HOURS * * * * *
# (75, 8824, 53, 10)
#  PREP/INITIAL DATES * * * * * * *
# (75, 10569, 74, 10)
#  DACA67-02-D-2012  0004 * * *
# (424, 2685, 89, 10)
#  ACCIDENT REPORTING *
# (75, 2819, 82, 10)
#  No activities were started or finished today * * * *
# (85, 7245, 167, 10)
#  Page 2 of 2 * *
# (494, 4323, 38, 10)
#  EQUIPMENT HOURS * *
# (75, 4387, 70, 10)
#  PROJECT * *
# (75, 1835, 30, 8)
#  03 Nov 2004 - Wednesday
# (424, 3504, 90, 10)
#  No QC requirements were completed today * *
# (85, 3907, 169, 10)
#  QC NARRATIVES * * * * * *
# (75, 9470, 61, 10)
#  (Describe accidents) * *
# (170, 4432, 70, 10)
#  REPORT NUMBER *
# (417, 948, 56, 8)
#  SUPERINTENDENT'S INITIALS * * *
# (369, 6645, 94, 8)
#  CONTRACT NUMBER * * * * * * * * * *
# (417, 8571, 66, 8)
#  QUALITY CONTROL TESTING AND RESULTS
# (95, 303, 152, 18)
#  DACA67-02-D-2012  0004 * * * * * * * * * * * * * *
# (424, 11947, 89, 10)
#  QC REQUIREMENTS
# (75, 509, 70, 10)
#  EQUIPMENT HOURS
# (75, 685, 70, 10)
#  Parsons Evergreene Construction, L.L.C.
# (82, 8602, 139, 10)
#  No contractors had their first or last day on site today * * * *
# (85, 7350, 206, 10)
# Temperature Min 39 °F, Max 48 °F 0.12 IN Precipitation 20 MPH Wind
# (319, 3544, 233, 28)
#  QA/QC PUNCH LIST *
# (75, 2325, 70, 10)
# None today * * * * * * *
# (95, 2148, 163, 18)
#  QUALITY CONTROL TESTING AND RESULTS * * *
# (95, 5355, 152, 18)
#  QUALITY CONTROL TESTING AND RESULTS * * * * * *
# (95, 10407, 152, 18)
#  On behalf of the contractor, I certify that this Report is complete and correct and all equipment and * * * * * * *
# (183, 11660, 386, 33)
# Worked * *
# (508, 4017, 26, 20)
#  Hours * * * * *
# (509, 8841, 26, 20)
#  Total operating hours to date: 0.0 * * * *
# (95, 7783, 112, 10)
#  PREPARATORY AND/OR INITIALS HELD TODAY * * * * * *
# (95, 10508, 163, 18)
#  CONTRACTOR * * * * * * *
# (75, 10278, 45, 8)
#  SUPERINTENDENT'S INITIALS *
# (369, 3277, 94, 8)
#  PROJECT * * * * * * * * * * * * * *
# (75, 11939, 30, 8)
#  General Comments: * * * * *
# (85, 9487, 78, 10)
# DATE * * * * * *
# (417, 5166, 16, 22)
#  95 *
# (417, 7691, 16, 22)
#  (Describe QC Punch List items issued, Report QC and QA Punch List items corrected) * * * * *
# (170, 8750, 290, 10)
#  ACCIDENT REPORTING * * * *
# (75, 7799, 82, 10)
#  LABOR HOURS * * *
# (75, 5683, 53, 10)
#  The following labor hours were Reported today: * * * * *
# (85, 8838, 186, 10)
#  0.0
# (532, 654, 10, 20)
# None today * * * * * * * * * * *
# (95, 3765, 163, 18)
# 0.0 * * * * * *
# (532, 2745, 10, 20)
#  0.0 *
# (532, 2744, 10, 20)
#  CONTRACT NUMBER * * * * * * * * * * * *
# (417, 10255, 65, 8)
#  No QC requirements were completed today * * * * * * *
# (85, 10681, 169, 10)
#  QC REPRESENTATIVE'S SIGNATURE * * * * *
# (71, 9174, 115, 8)
#  ACCIDENT REPORTING
# (75, 1019, 82, 10)
#  PROJECT * * * *
# (75, 3519, 30, 8)
#  CONTRACTORS ON SITE (Report first and/or last day contractors w ere on site)
# (75, 2369, 278, 10)
# DATE * * *
# (417, 2640, 16, 22)
# No safety issues
# (95, 3739, 101, 18)
#  Page 1 of 2 *
# (494, 1797, 38, 10)
#  Safety Inspection / Safety Meetings: * *
# (85, 3728, 138, 10)
#  No equipment hours were Reported today * * * * * *
# (85, 9916, 163, 10)
#  Labor Classification * * * * * *
# (197, 12454, 78, 34)
#  DACA67-02-D-2012  0004 * * * * * * * *
# (424, 6895, 89, 10)
#  REPORT NUMBER * * * * * * * * * * * * * *
# (417, 11894, 56, 8)
#  CONTRACTORS FIRST AND/OR LAST DAY ONSITE * * *
# (95, 7157, 175, 18)
#  DAILY SAFETY INSPECTIONS * * * *
# (95, 7106, 101, 18)
#  D/B Replace Military Family Housing P5 * * * * * * * * *
# (82, 7737, 130, 10)
#  QUALITY CONTROL INSPECTIONS AND RESULTS * * * * * *
# (95, 12065, 168, 18)
#  (Preparatory and initial dates held and advance notice) * * * * *
# (170, 8659, 185, 10)
# Asbestos Abatement * * *
# (95, 5711, 112, 37)
#  (Describe accidents)
# (170, 1019, 70, 10)
# DATE * * * * * * * * * * * * * *
# (417, 11902, 19, 22)
#  Activities in Progress: * * * * * *
# (85, 12013, 86, 10)
#  Employer
# (95, 641, 92, 37)
#  DATE * * * * * * * *
# (281, 8329, 16, 8)
#  QUALITY CONTROL TESTING AND RESULTS * *
# (95, 3671, 152, 18)
# None *
# (95, 5381, 35, 18)
# Temperature Min 28 °F, Max 53 °F No Precipitation 29 MPH Wind
# (319, 1860, 219, 28)
#  EQUIPMENT HOURS * * * *
# (75, 7755, 70, 10)
#  Page 1 of 2 * * *
# (494, 5165, 38, 10)
#  CONTRACTORS QUALITY CONTROL REPORT (QCR) * * *
# (123, 2636, 227, 12)
#  (Preparatory and initial dates held and advance notice) * * * * * *
# (170, 9693, 185, 10)
# All other Work for New  Family
# (156, 10628, 101, 20)
#  Page 2 of 2 *
# (494, 2639, 38, 10)
# 0.0 * * * * * * *
# (441, 4018, 36, 44)
#  CONTRACTOR CERTIFICATION * * * * * * *
# (71, 11662, 98, 8)
#  D/B Replace Military Family Housing P5 * * * * * *
# (82, 5211, 130, 10)
#  DACA67-02-D-2012  0004 * *
# (424, 1843, 89, 10)
#  No preparatory or initial inspections were held today * * * * *
# (85, 8672, 204, 10)
# None today * * * * * * * * * * * * * * * * * * * * *
# (95, 9498, 168, 18)
# plans and specifications, to the best of my knowledge, except as noted above. * * * * * * *
# (183, 11662, 386, 33)
# Temperature Min 23 °F, Max 39 °F No Precipitation 29 MPH Wind
# (319, 8596, 219, 28)
#  (Describe accidents) * * * * *
# (170, 8940, 71, 10)
# Weather Caused No Delay * * * * *
# (319, 8595, 219, 28)
#  CONTRACTORS QUALITY CONTROL REPORT (QCR) * *
# (123, 1794, 227, 12)
#  No contractors had their first or last day on site today
# (85, 597, 206, 10)
#  REPORT NUMBER * * * * * * * * *
# (417, 7684, 56, 8)
#  The following labor hours were Reported today: * *
# (85, 4012, 186, 10)
# 0.0 * * * * * * * * * * * * * * * * * * *
# (464, 11195, 10, 20)
#  No preparatory or initial inspections were held today *
# (85, 2247, 203, 10)
#  Description *
# (197, 11181, 47, 23)
#  WEATHER * * *
# (319, 5226, 219, 28)
# None
# (95, 3697, 35, 18)
#  (Describe accidents) * * * *
# (170, 7800, 70, 10)
# None today * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# (95, 12193, 163, 18)
#  DAILY SAFETY INSPECTIONS * *
# (95, 3738, 101, 18)
#  QUALITY CONTROL TESTING AND RESULTS * * * * *
# (95, 9522, 152, 18)
#  CONTRACTOR CERTIFICATION
# (71, 1558, 98, 8)
#  Serial Number
# (95, 11181, 116, 37)
# Weather Caused No Delay * * * * * * *
# (319, 10279, 219, 28)
#  QC REQUIREMENTS * * *
# (75, 5578, 70, 10)
#  Total
# (417, 665, 16, 10)
# Asbestos Abatement * * * * * * * *
# (95, 12456, 116, 47)
#  No contractors had their first or last day on site today * *
# (85, 3982, 206, 10)
#  Total operating hours to date: 0.0 *
# (95, 2802, 112, 10)
#  On behalf of the contractor, I certify that this Report is complete and correct and all equipment and * * * * * *
# (183, 9976, 386, 33)
#  Number of
# (441, 631, 36, 44)
#  01 Nov 2004 - Monday
# (424, 136, 76, 10)
# 001
# (95, 11182, 116, 37)
# Weather Caused No Delay * *
# (319, 3543, 233, 28)
#  QC NARRATIVES * * *
# (75, 5260, 61, 10)
# Temperature Min 34 °F, Max 41 °F 0.04 IN Precipitation 8 MPH Wind
# (319, 9438, 229, 28)
#  QC REPRESENTATIVE'S SIGNATURE
# (71, 1595, 115, 8)
#  PREPARATORY AND/OR INITIALS HELD TODAY * * * * * * *
# (95, 12192, 163, 18)
# NA
# (95, 2199, 91, 18)
#  SUPERINTENDENT'S INITIALS * * * * * *
# (369, 10013, 94, 8)
#  ACCIDENT REPORTING * * *
# (75, 6115, 82, 10)
#  PREP/INITIAL DATES * * * *
# (75, 7201, 74, 10)
#  Total * * * * * * * *
# (417, 12488, 16, 10)
#  DATE * * * * * * * * * *
# (281, 9172, 16, 8)
#  DACA67-02-D-2012  0004 * * * * * *
# (424, 5211, 89, 10)
#  PROJECT * * * * * * *
# (75, 6045, 30, 8)
#  REPORT NUMBER * * * * * * * * * *
# (417, 8526, 56, 8)
# Temperature Min 34 °F, Max 51 °F 0.15 IN Precipitation 13 MPH Wind
# (319, 11964, 233, 28)
# No safety issues * * * * *
# (95, 12168, 101, 18)
#  D/B Replace Military Family Housing P5 * * *
# (82, 2685, 130, 10)
#  (Describe QC Punch List items issued, Report QC and QA Punch List items corrected) * * *
# (170, 5609, 290, 10)
#  No preparatory or initial inspections were held today * * *
# (85, 5531, 203, 10)
#  AAI * *
# (95, 3603, 164, 18)
#  Number of * * *
# (441, 5700, 36, 44)
#  OPERATING ENGINEER
# (197, 11123, 78, 10)
#  No accidents reported today * * * *
# (85, 7813, 109, 10)
#  QA/QC PUNCH LIST * * *
# (75, 5608, 70, 10)
# None today * * * * * * * * * * * * * * * * * * * * * * * * *
# (95, 10408, 152, 18)
#  DATE * * * * * * * * * * * * * * *
# (508, 11697, 16, 8)
#  Evergreene Construction, L.C. * *
# (82, 3550, 102, 10)
#  On behalf of the contractor, I certify that this Report is complete and correct and all equipment and * * * *
# (183, 8292, 386, 33)
#  DAILY SAFETY INSPECTIONS * * * * * *
# (95, 10483, 101, 18)
#  Number of * * * * * * *
# (441, 12445, 36, 54)
#  (Describe accidents) *
# (170, 2819, 70, 10)
#  Page 2 of 2 * * * * *
# (494, 11059, 38, 10)
#  Total hours w orked to date: 0.0
# (95, 9886, 112, 10)
#  Page 1 of 2 * * * * * *
# (494, 11901, 38, 10)
#  CONTRACTORS QUALITY CONTROL REPORT (QCR) *
# (123, 952, 227, 12)
#  (Preparatory and initial dates held and advance notice) * * * *
# (170, 7201, 185, 10)
#  10.0
# (527, 11123, 14, 20)
#  20.0
# (527, 12468, 14, 30)
# material used and work performed during this Reporting period are in compliance with the contract * *
# (183, 4925, 386, 33)
# 0.0 * * * * * * * * * * * * * * *
# (532, 7408, 10, 20)
#  QUALITY CONTROL INSPECTIONS AND RESULTS
# (95, 2021, 168, 18)
#  CONTRACT NUMBER * * * * *
# (417, 4361, 65, 8)
#  DAILY LOG OF CONSTRUCTION - MILITARY * * * * * * * * *
# (137, 7701, 192, 12)
#  QUALITY CONTROL TESTING AND RESULTS * * * *
# (95, 7039, 152, 18)
#  No QC requirements were completed today * * * * *
# (85, 8733, 169, 10)
#  No QC Punch List items were issued today * * *
# (85, 5622, 165, 24)
#  REMARKS *
# (95, 2071, 38, 18)
#  WEATHER * * * *
# (319, 6910, 219, 28)
#  Safety Inspection / Safety Meetings: * * * *
# (85, 7096, 138, 10)
#  EQUIPMENT HOURS * * * * * *
# (75, 9903, 70, 10)
# Demolished building 4264 - crunching and hauling demolition debris.
# (95, 12024, 231, 18)
#  Activities in Progress:
# (85, 225, 86, 10)
#  Total operating hours to date: 0.0
# (95, 712, 112, 10)
#  CONTRACTORS ON SITE (Report first and/or last day contractors w ere on site) * * *
# (75, 7336, 278, 10)
# 0.0 * * * * * * * * * * * * * *
# (441, 7387, 36, 44)
# None today * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# (95, 12219, 175, 18)
# Temperature Min 35 °F, Max 46 °F No Precipitation 12 MPH Wind
# (319, 10280, 219, 28)
#  CONTRACTORS ON SITE (Report first and/or last day contractors w ere on site) * * * *
# (75, 8794, 278, 10)
#  WEATHER *
# (319, 1858, 219, 28)
#  No activities were started or finished today * * * * * * *
# (85, 12306, 167, 10)
#  No QC requirements were completed today * * *
# (85, 5591, 169, 10)
#  Employer * *
# (95, 4026, 112, 37)
#  QC REQUIREMENTS * * * * * * *
# (75, 10667, 70, 10)
#  General Comments: *
# (85, 2010, 78, 10)
#  (Describe QC Punch List items issued, Report QC and QA Punch List items corrected) * * * * * * * *
# (170, 12353, 290, 10)
# No Punch List items were corrected today * *
# (85, 3939, 165, 24)
#  D/B Replace Military Family Housing P5 * * * * * * * * * * *
# (82, 9421, 130, 10)
# 30.0
# (527, 12470, 14, 30)
#  10 Nov 2004 - Wednesday
# (424, 11924, 90, 10)
#  CONTRACTORS QUALITY CONTROL REPORT (QCR) * * * * * *
# (123, 5162, 227, 12)
# LABORERS
# (197, 10800, 67, 23)
#  SUPERINTENDENT'S INITIALS
# (369, 1593, 94, 8)
#  Employer * * * *
# (95, 7394, 112, 37)
#  REMARKS
# (95, 328, 59, 18)
#  DAILY LOG OF CONSTRUCTION - MILITARY *
# (137, 965, 192, 12)
# plans and specifications, to the best of my knowledge, except as noted above. *
# (183, 3242, 386, 33)
#  Employer *
# (95, 2731, 112, 37)
#  DAILY LOG OF CONSTRUCTION - MILITARY * * *
# (137, 2649, 192, 12)
#  REPORT NUMBER * * * * * * * *
# (417, 6842, 56, 8)
#  DATE * * *
# (508, 3277, 16, 8)
# 0.0 * * * * * * * * * * * * * * * * *
# (441, 8844, 36, 44)
#  Safety Inspection / Safety Meetings: * * * * * *
# (85, 10473, 138, 10)
#  PROJECT * * * * * * * * * * * *
# (75, 10255, 30, 8)
# OPERATING ENGINEER
# (85, 630, 189, 50)
#  REMARKS * * * * * *
# (95, 10432, 35, 18)
#  (Describe QC Punch List items issued, Report QC and QA Punch List items corrected) * * * * * * *
# (170, 10698, 290, 10)
#  DAILY LOG OF CONSTRUCTION - MILITARY * * * * * * *
# (137, 6017, 192, 12)
# No Punch List items were corrected today * * * * *
# (85, 8765, 165, 24)
#  No accidents reported today * * * * * *
# (85, 9961, 109, 10)
#  D/B Replace Military Family Housing P5 *
# (82, 1001, 130, 10)
#  Labor Classification * * * * *
# (197, 10799, 67, 23)
#  No activities were started or finished today * * * * *
# (85, 8702, 167, 10)
#  WEATHER * * * * *
# (319, 8594, 219, 28)
#  05 Nov 2004 - Friday
# (424, 6872, 70, 10)
# Asbestos Abatement * * * * * *
# (95, 10800, 71, 23)
#  PROJECT * * * * *
# (75, 4361, 30, 8)
#  ACTIVITY START/FINISH * * * * *
# (75, 8689, 89, 10)
#  General Comments: * * * *
# (85, 7003, 78, 10)
#  QC NARRATIVES *
# (75, 1892, 61, 10)
#  01 Nov 2004 - Monday *
# (424, 978, 76, 10)
#  ACTIVITY START/FINISH * * * * * * * *
# (75, 12292, 89, 10)
#  D/B Replace Military Family Housing P5 * * * * * * * * * * * * * *
# (82, 11947, 130, 10)
# Total hours w orked to date: 0.0 * *
# (95, 5712, 112, 37)
#  QA/QC PUNCH LIST
# (75, 539, 70, 10)
#  PREP/INITIAL DATES * * * * * *
# (75, 9693, 74, 10)
# OPERATING ENGINEER * * *
# (197, 5711, 78, 23)
#  AAI *
# (95, 1970, 166, 18)
#  CONTRACTORS QUALITY CONTROL REPORT (QCR) * * * * * * *
# (123, 6004, 227, 12)
#  02 Nov 2004 - Tuesday
# (424, 1820, 79, 10)
#  Total operating hours to date: 0.0 * *
# (95, 4415, 112, 10)
#  No contractors had their first or last day on site today * * * * *
# (85, 8807, 206, 10)
#  No preparatory or initial inspections were held today
# (85, 462, 202, 10)
# None today * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# (95, 12092, 152, 18)
#  100
# (417, 11901, 19, 22)
#  QC REQUIREMENTS * * * *
# (75, 7262, 70, 10)
#  AAI * * * * *
# (95, 10339, 89, 18)
#  Activities in Progress: * * * * *
# (85, 10329, 86, 10)
# None today * * * * * * * * * * * * * * * * * * * * * *
# (95, 9523, 152, 18)
# Asbestos Abatement *
# (95, 2732, 112, 37)
#  No equipment hours were Reported today * * * * *
# (85, 8909, 163, 10)
#  QA/QC PUNCH LIST * *
# (75, 3924, 70, 10)
#  LABOR HOURS * * * * * * *
# (75, 10772, 53, 10)
#  ACTIVITY START/FINISH * * *
# (75, 5548, 89, 10)
# material used and work performed during this Reporting period are in compliance with the contract * * *
# (183, 6609, 386, 33)
#  09 Nov 2004 - Tuesday
# (424, 10240, 79, 10)
#  Total * * * * * *
# (417, 11134, 16, 10)
#  QA/QC PUNCH LIST * * * * *
# (75, 8750, 71, 10)
#  No accidents reported today * * * * * * *
# (85, 11239, 109, 10)
#  Total * * * *
# (417, 7418, 16, 10)
#  PREP/INITIAL DATES * * * * * * * *
# (75, 12261, 74, 10)
#  (Describe QC Punch List items issued, Report QC and QA Punch List items corrected) * * * * * *
# (170, 9785, 290, 10)
#  WEATHER * *
# (319, 3542, 233, 28)
# 0.0 * * * * * * * * * * * * * * * *
# (441, 8843, 36, 44)
# Worked * * *
# (508, 5701, 26, 20)
# Demolished building #4215
# (95, 10340, 89, 18)
#  REMARKS * * * *
# (95, 7064, 35, 18)
#  0.0 * *
# (532, 4039, 10, 20)
# DATE * * * * * * *
# (417, 6008, 16, 22)
#  DATE
# (281, 1593, 16, 8)
#  REMARKS * * * * * * *
# (95, 12116, 257, 18)
# Temperature Min 21 °F, Max 44 °F No Precipitation No Wind
# (319, 176, 203, 28)
# 0.0 * * * * * * * * *
# (532, 4040, 10, 20)
# No Punch List items were corrected today * * * *
# (85, 7307, 165, 24)
#  ACCIDENT REPORTING * * * * * *
# (75, 9947, 82, 10)
#  CONTRACT NUMBER * * * * * * * * * * * * * *
# (417, 11939, 65, 8)
# None today * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# (95, 12066, 168, 18)
#  (Preparatory and initial dates held and advance notice) * *
# (170, 3833, 185, 10)
# None today * * * * * * * * * * * * * *
# (95, 5356, 152, 18)
#  QC REQUIREMENTS * *
# (75, 3894, 70, 10)
# None today * * *
# (95, 2022, 168, 18)
#  Safety Inspection / Safety Meetings: *
# (85, 2112, 138, 10)
#  RFI&ampRFP STATUS UPDATE
# (95, 2198, 91, 18)
#  06 Nov 2004 - Saturday
# (424, 8556, 80, 10)
#  DACA67-02-D-2012  0004 *
# (424, 1001, 89, 10)
#  Activity No
# (95, 10627, 36, 20)
#  CONTRACTOR *
# (75, 1858, 45, 8)
#  CONTRACTORS QUALITY CONTROL REPORT (QCR) * * * * * * * * *
# (123, 7688, 227, 12)
# OPERATING ENGINEER * *
# (197, 4027, 78, 23)
# Total hours w orked to date: 15.0
# (95, 11124, 116, 24)
#  Evergreene Construction, L.C. * * * *
# (82, 6918, 102, 10)
#  QC REQUIREMENTS * * * * * *
# (75, 9754, 70, 10)
#  No activities were started or finished today * *
# (85, 3877, 167, 10)
# None today * * * * * * * *
# (95, 2174, 175, 18)
# No remarks today
# (95, 329, 59, 18)
#  REPORT NUMBER * *
# (417, 1790, 56, 8)
#  CONTRACT NUMBER * * * * * * *
# (417, 6045, 65, 8)
# outage!
# (95, 9550, 430, 27)
#  0.0 * * *
# (532, 5723, 10, 20)
#  No accidents reported today * * *
# (85, 6129, 109, 10)
# No Punch List items were corrected today * * *
# (85, 5623, 165, 24)
#  D/B Replace Military Family Housing P5 * * * * * * * * * * * * *
# (82, 11105, 130, 10)
#  CONTRACTORS ON SITE (Report first and/or last day contractors were on site)
# (75, 583, 276, 10)
#  Evergreene Construction, L.C. * * * * *
# (82, 9444, 102, 10)
# 2.0
# (464, 11124, 10, 20)
#  0.0 * * * *
# (532, 7407, 10, 20)
# None today * * * * * *
# (95, 2123, 101, 18)
# None today * * * * * * * * * * * *
# (95, 3790, 175, 18)
# Hours
# (441, 11172, 27, 20)
#  Number of *
# (441, 2720, 36, 44)
#  SUPERINTENDENT'S INITIALS * * * * * * *
# (369, 11697, 94, 8)
# OPERATING ENGINEER *
# (197, 2732, 78, 23)
#  Total * * * * *
# (418, 8875, 16, 10)
#  No QC Narratives were reported today
# (85, 8642, 147, 10)
#  D/B Replace Military Family Housing P5 * * * * *
# (82, 4369, 130, 10)
#  Page 2 of 2 * * *
# (494, 6007, 38, 10)
#  CONTRACTOR * * * *
# (75, 6910, 45, 8)
# 10.0
# (527, 11195, 14, 20)
#  Number of * * * * * *
# (441, 10789, 36, 34)
#  DACA67-02-D-2012  0004 * * * *
# (424, 3527, 89, 10)
#  (Describe QC Punch List items issued, Report QC and QA Punch List items corrected) *
# (170, 2325, 290, 10)
# Total hours worked to date:
# (95, 643, 92, 37)
#  CONTRACTORS FIRST AND/OR LAST DAY ONSITE
# (95, 2173, 175, 18)
#  No equipment hours were Reported today
# (85, 699, 162, 10)
#  REPORT NUMBER * * * *
# (417, 3474, 56, 8)
#  No activities were started or finished today * * *
# (85, 5561, 167, 10)
# DATE * * * * * * * * * * * *
# (417, 10218, 16, 22)
# plans and specifications, to the best of my knowledge, except as noted above. * * * * *
# (183, 9136, 387, 33)
#  ACTIVITY START/FINISH * * * * * *
# (75, 9724, 89, 10)
#  (Describe accidents) * * *
# (170, 6116, 70, 10)
#  The following labor hours were Reported today: * * *
# (85, 5696, 186, 10)
#  QUALITY CONTROL INSPECTIONS AND RESULTS * * * * *
# (95, 10381, 168, 18)
#  PROJECT * * * * * * * * *
# (75, 7729, 30, 8)
#  Page 1 of 2 * *
# (494, 3481, 38, 10)
# No safety issues *
# (95, 5423, 101, 18)
#  CONTRACTORS ON SITE (Report first and/or last day contractors w ere on site) * *
# (75, 5652, 278, 10)
#  SUPERINTENDENT'S INITIALS * * * *
# (369, 8329, 94, 8)
# 0.0 *
# (441, 633, 36, 44)
#  QA/QC PUNCH LIST * * * * * * * *
# (75, 12353, 70, 10)
# 1.0
# (441, 10791, 36, 34)
#  WEATHER
# (319, 174, 203, 28)
# 0.0 * *
# (441, 634, 36, 44)
# No safety issues * *
# (95, 7107, 101, 18)
#  No accidents reported today *
# (85, 2832, 109, 10)
#  No equipment hours were Reported today * *
# (85, 4401, 163, 10)
#  (Preparatory and initial dates held and advance notice) * * *
# (170, 5517, 185, 10)
#  On behalf of the contractor, I certify that this Report is complete and correct and all equipment and *
# (183, 3240, 386, 33)
# Employees * * * *
# (441, 7385, 36, 44)
#  The following equipment hours were Reported today:
# (85, 11167, 209, 10)
#  No preparatory or initial inspections were held today * * * * * * * *
# (85, 12275, 203, 10)
#  DATE * * * * * *
# (281, 6645, 16, 8)
#  Page 2 of 2 * * * *
# (494, 7691, 38, 10)
#  No QC Punch List items were issued today *
# (85, 2338, 165, 24)
#  DAILY SAFETY INSPECTIONS
# (95, 370, 101, 18)
#  No accidents reported today
# (85, 1033, 109, 10)
#  Safety Inspection / Safety Meetings: * * * * *
# (85, 9588, 138, 10)
#  DATE * * * * * * * * * * * * * *
# (281, 11697, 16, 8)
#  DAILY SAFETY INSPECTIONS * * * * *
# (95, 9599, 101, 18)
#  CONTRACTORS QUALITY CONTROL REPORT (QCR) * * * * * * * * * * * *
# (123, 10214, 227, 12)
# None today * * * * * * * * * * * * * * * * * * * * * * *
# (95, 9650, 175, 18)
#  DAILY LOG OF CONSTRUCTION - MILITARY
# (137, 123, 192, 12)
#  QC REQUIREMENTS *
# (75, 2295, 70, 10)
#  CONTRACT NUMBER
# (417, 151, 65, 8)
# plans and specifications, to the best of my knowledge, except as noted above.
# (183, 1558, 386, 33)
#  CONTRACTOR * * *
# (75, 5226, 45, 8)
#  CONTRACT NUMBER * * * * * * * *
# (417, 6887, 65, 8)
#  No equipment hours were Reported today *
# (85, 2788, 163, 10)
# 0.0 * * *
# (532, 655, 10, 20)
#  Employer * * *
# (95, 5710, 112, 37)
#  AAI
# (95, 235, 199, 18)
#  Employer * * * * * * *
# (95, 12454, 116, 47)
#  No activities were finished today
# (85, 10650, 126, 10)
#  DACA67-02-D-2012  0004 * * * * * * * * * * * *
# (424, 10263, 89, 10)
# 0.0 * * * * * * * * * * * *
# (532, 5724, 10, 20)
# P5410
# (95, 10628, 36, 20)
#  DATE * * * * * * * * * * * * *
# (508, 10013, 16, 8)
#  Hours *
# (508, 2720, 26, 20)
#  D/B Replace Military Family Housing P5 * * * * * * * *
# (82, 6895, 130, 10)
#  AAI * * * *
# (95, 6971, 164, 18)
#  DATE * *
# (281, 3277, 16, 8)
#  SUPERINTENDENT'S INITIALS * * * * *
# (370, 9172, 94, 8)
#  PREPARATORY AND/OR INITIALS HELD TODAY * *
# (95, 3764, 163, 18)
#  Hours * * *
# (508, 5700, 26, 20)
#  (Describe accidents) * * * * * *
# (170, 9947, 70, 10)
#  CONTRACTOR * * * * *
# (75, 8594, 45, 8)
#  Hours
# (508, 631, 26, 20)
# Total hours w orked to date: 0.0
# (95, 2733, 112, 37)
# 2.0 *
# (441, 12447, 36, 54)
#  CONTRACTOR * *
# (75, 3542, 45, 8)
#  No preparatory or initial inspections were held today * * * * * *
# (85, 9707, 203, 10)
#  REPORT NUMBER * * * * * * * * * * *
# (417, 9368, 56, 8)
#  The following labor hours were Reported today:
# (85, 628, 189, 50)
#  Total * *
# (417, 4050, 16, 10)
#  QUALITY CONTROL TESTING AND RESULTS *
# (95, 2046, 152, 18)
#  (Preparatory and initial dates held and advance notice)
# (170, 448, 185, 10)
#  QC NARRATIVES * * * * * * * *
# (75, 11996, 61, 10)
#  5.0
# (532, 10813, 10, 10)
#  D/B Replace Military Family Housing P5 * *
# (82, 1843, 130, 10)
# Weather Caused No Delay
# (319, 175, 203, 28)
#  REPORT NUMBER * * * * *
# (417, 4316, 56, 8)
#  Total operating hours to date: 0.0 * * * * * *
# (95, 9930, 112, 10)
#  DAILY CONTROL INSPECTIONS AND RESULTS
# (95, 277, 158, 18)
#  General Comments: * * * * * * *
# (85, 12055, 78, 10)
#  On behalf of the contractor, I certify that this Report is complete and correct and all equipment and * * *
# (183, 6608, 386, 33)
#  PROJECT
# (75, 151, 30, 8)
#  DATE * * * * * * * * *
# (508, 8329, 16, 8)
#  LABOR HOURS * *
# (75, 3999, 53, 10)
# DATE * * * * * * * *
# (417, 6850, 16, 22)
#  REPORT NUMBER
# (417, 106, 56, 8)
# None today * * * * * * * * * * * * * * * * * * * * * * * * * * *
# (95, 10535, 175, 18)
# Worked * * * *
# (508, 7385, 26, 20)
# None today *
# (95, 304, 152, 18)
#  92 *
# (417, 2639, 16, 22)
# Weather Caused No Delay *
# (319, 1859, 219, 28)
#  No QC Punch List items were issued today * * * * * *
# (85, 9798, 165, 24)
# 15.0
# (527, 11124, 14, 20)
#  EVERGREENE MANAGEMENT
# (95, 1919, 432, 44)
#  ACCIDENT REPORTING * * * * * * *
# (75, 11225, 82, 10)
#  CONTRACTORS QUALITY CONTROL REPORT (QCR) * * * *
# (123, 3478, 227, 12)
# Worked on shutting down water and removing refrigerators
# (95, 236, 199, 18)
# Link Belt 2800
# (197, 11182, 47, 23)
#  No QC Punch List items were issued today * * * *
# (85, 7306, 165, 24)
#  PROJECT * * * * * *
# (75, 5203, 30, 8)
#  CONTRACTORS QUALITY CONTROL REPORT (QCR) * * * * * * * * * *
# (123, 8530, 228, 12)
#  No equipment hours were Reported today * * *
# (85, 6085, 163, 10)
#  DATE * * * * * * * * * * *
# (509, 9172, 16, 8)
#  QUALITY CONTROL INSPECTIONS AND RESULTS *
# (95, 3645, 168, 18)
#  REMARKS * *
# (95, 3696, 35, 18)
#  Page 2 of 2
# (494, 955, 38, 10)
#  ACTIVITY START/FINISH * * * *
# (75, 7232, 89, 10)
#  ACTIVITY START/FINISH *
# (75, 2264, 89, 10)
#  DACA67-02-D-2012  0004 * * * * *
# (424, 4369, 89, 10)
#  EQUIPMENT HOURS *
# (75, 2774, 70, 10)
#  03 Nov 2004 - Wednesday *
# (424, 4346, 90, 10)
# Hours *
# (508, 11172, 33, 20)
# Held demo prep meeting today with AAI.  See attached minutes of meeting.  Will start next week with demo.  They brought new
# (95, 397, 427, 27)
#  No activities were started or finished today
# (85, 492, 165, 10)
#  QUALITY CONTROL INSPECTIONS AND RESULTS * *
# (95, 5329, 168, 18)
#  On behalf of the contractor, I certify that this Report is complete and correct and all equipment and * *
# (183, 4924, 386, 33)
#  DAILY LOG OF CONSTRUCTION - MILITARY * * * * * * * * * * * * *
# (137, 11069, 192, 12)
# Labor Classification
# (85, 629, 189, 50)
# Asbestos Abatement
# (95, 642, 92, 37)
# material used and work performed during this Reporting period are in compliance with the contract * * * * *
# (183, 9135, 387, 33)
#  PROJECT * * * * * * * * * * *
# (75, 9413, 30, 8)
#  (Describe QC Punch List items issued, Report QC and QA Punch List items corrected) * *
# (170, 3925, 290, 10)
#  No activities were started or finished today *
# (85, 2278, 167, 10)
#  0.0 * * * * *
# (532, 8865, 10, 20)
#  Number of * *
# (441, 4016, 36, 44)
#  CONTRACT NUMBER * * * * * *
# (417, 5203, 65, 8)
# 10.0 *
# (527, 12469, 14, 30)
#  REPORT NUMBER * * * * * * * * * * * * *
# (417, 11052, 56, 8)
#  LABOR HOURS *
# (75, 2703, 53, 10)
# DATE * * * * * * * * * * * * *
# (417, 11060, 16, 22)
# Asbestos Abatement * * * * * * *
# (95, 12455, 116, 47)
# Weather Caused No Delay * * *
# (319, 5227, 219, 28)
#  D/B Replace Military Family Housing P5 * * * * * * * * * * * *
# (82, 10263, 130, 10)
# 0.0 * * * * * * * * * *
# (441, 5702, 36, 44)
#  CONTRACTOR
# (75, 174, 45, 8)
#  02 Nov 2004 - Tuesday *
# (424, 2662, 79, 10)
# Shutting dow n w ater and removing refrigerators * *
# (95, 6972, 164, 18)
# Employees * * * * *
# (441, 8842, 36, 44)
#  DAILY SAFETY INSPECTIONS *
# (95, 2122, 101, 18)
#  CONTRACTORS ON SITE (Report first and/or last day contractors w ere on site) *
# (75, 3968, 278, 10)
# None today * * * * *
# (95, 2072, 38, 18)
#  No QC requirements were completed today *
# (85, 2308, 169, 10)
# material used and work performed during this Reporting period are in compliance with the contract * * * * * *
# (183, 9977, 386, 33)
#  DAILY SAFETY INSPECTIONS * * *
# (95, 5422, 101, 18)
# material used and work performed during this Reporting period are in compliance with the contract
# (183, 1557, 386, 33)
#  Safety Inspection / Safety Meetings: * * *
# (85, 5412, 138, 10)
# No Punch List items were corrected today *
# (85, 2339, 165, 24)
#  CONTRACTOR CERTIFICATION * *
# (71, 4926, 98, 8)
#  QC NARRATIVES * *
# (75, 3576, 61, 10)
# material used and work performed during this Reporting period are in compliance with the contract *
# (183, 3241, 386, 33)
#  No QC requirements were completed today
# (85, 522, 167, 10)
#  The following labor hours were Reported today: *
# (85, 2717, 186, 10)
#  Safety Inspection / Safety Meetings: * * * * * * *
# (85, 12157, 138, 10)
#  AAI(cid:31)
# (95, 12023, 231, 18)
#  DAILY LOG OF CONSTRUCTION - MILITARY * * * * * * * * * * * * * *
# (137, 11911, 192, 12)
#  DAILY LOG OF CONSTRUCTION - MILITARY * * * * * * * * * *
# (137, 8543, 192, 12)
# Employees *
# (441, 2721, 36, 44)
#  91 *
# (417, 955, 16, 22)
#  CONTRACTORS QUALITY CONTROL REPORT (QCR) * * * * * * * * * * * * * *
# (123, 11898, 227, 12)
#  No contractors had their first or last day on site today *
# (85, 2383, 206, 10)
#  1.0
# (464, 11123, 10, 20)
#  EQUIPMENT HOURS * * * * *
# (75, 8896, 70, 10)
#  Employer * * * * *
# (95, 8851, 112, 37)
#  DAILY LOG OF CONSTRUCTION - MILITARY * * * * *
# (137, 4333, 192, 12)
# 1.0 *
# (441, 12448, 36, 54)
#  DAILY LOG OF CONSTRUCTION - MILITARY * * * *
# (137, 3491, 192, 12)
# plans and specifications, to the best of my knowledge, except as noted above. * * *
# (183, 6610, 386, 33)
#  WEATHER * * * * * * *
# (319, 10278, 219, 28)
#  DATE * * * * *
# (508, 4961, 16, 8)
#  LABOR HOURS * * * *
# (75, 7367, 53, 10)
# material used and work performed during this Reporting period are in compliance with the contract * * * * * * *
# (183, 11661, 386, 33)
#  Labor Classification *
# (197, 4026, 78, 23)
#  05 Nov 2004 - Friday *
# (424, 7714, 70, 10)
#  Asbestos Abatement
# (95, 11123, 116, 24)
#  Number of * * * * *
# (441, 8841, 36, 44)
#  QC NARRATIVES * * * *
# (75, 6944, 61, 10)
# Did not finish.  NE area remains.  Scheduled to finish on Wednesday at 10:30 am.
# (95, 1923, 432, 44)
# OPERATING ENGINEER * * * *
# (197, 7395, 78, 23)
#  PREP/INITIAL DATES
# (75, 448, 74, 10)
#  AAI * * *
# (95, 5287, 164, 18)
# 0.0 * * * * * * * *
# (441, 4019, 36, 44)
#  (Describe QC Punch List items issued, Report QC and QA Punch List items corrected)
# (170, 540, 290, 10)
#  DACA67-02-D-2012  0004 * * * * * * *
# (424, 6053, 89, 10)
#  CONTRACT NUMBER *
# (417, 993, 65, 8)
# Shutting dow n w ater, and removing refrigerators
# (95, 1971, 166, 18)
#  PROJECT * * * * * * * *
# (75, 6887, 30, 8)
#  Safety Inspection / Safety Meetings:
# (85, 360, 138, 10)
# license, number was okay by Jim LaFluer.
# (95, 398, 427, 27)
#  Activities in Progress: * *
# (85, 3593, 86, 10)
#  PREPARATORY AND/OR INITIALS HELD TODAY *
# (95, 2147, 163, 18)
#  PROJECT * * *
# (75, 2677, 30, 8)
# No Punch List items were corrected today * * * * * *
# (85, 9799, 165, 24)
# Asbestos Abatement * *
# (95, 4027, 112, 37)
#  Evergreene Construction, L.C. *
# (82, 1866, 102, 10)
#  DAILY LOG OF CONSTRUCTION - MILITARY * * * * * * * *
# (137, 6859, 192, 12)
# None today * * * * * * * * * * * * * * * * * * * * * * * *
# (95, 10382, 168, 18)
#  Total *
# (417, 2754, 16, 10)
#  PREPARATORY AND/OR INITIALS HELD TODAY * * * * *
# (95, 9624, 297, 18)
#  CONTRACTORS ON SITE (Report first and/or last day contractors w ere on site) * * * * *
# (75, 9828, 278, 10)
# Held preparatory meeting today for HazMat w ith Steven Galley and AAI - see attatched.
# (95, 9625, 297, 18)
#  CONTRACT NUMBER * * *
# (417, 2677, 65, 8)
#  DAILY LOG OF CONSTRUCTION - MILITARY * * * * * * * * * * *
# (137, 9385, 192, 12)
#  CONTRACT NUMBER * * * * * * * * * * *
# (417, 9413, 65, 8)
#  PROJECT * * * * * * * * * *
# (75, 8571, 30, 8)
#  PREPARATORY AND/OR INITIALS HELD TODAY * * * *
# (95, 7132, 163, 18)
# DATE * * * * * * * * *
# (417, 7692, 16, 22)
# plans and specifications, to the best of my knowledge, except as noted above. * * * *
# (183, 8294, 386, 33)
# Total hours w orked to date: 45.0
# (95, 12457, 116, 47)
# OPERATING ENGINEER * * * * * *
# (197, 12456, 78, 34)
# Worked * * * * *
# (509, 8842, 26, 20)
#  PROJECT * * * * * * * * * * * * *
# (75, 11097, 30, 8)
#  No QC requirements were completed today * * * * * *
# (85, 9768, 169, 10)
#  QC REPRESENTATIVE'S SIGNATURE *
# (71, 3279, 115, 8)
#  ACTIVITY START/FINISH
# (75, 479, 89, 10)
#  Page 1 of 1
# (494, 8533, 38, 10)
# None today * * * * * * * * * * * * * * * * * *
# (95, 7040, 152, 18)
# Weather Caused No Delay * * * * * *
# (319, 9437, 229, 28)
#  PREP/INITIAL DATES * *
# (75, 3833, 74, 10)
#  PREP/INITIAL DATES *
# (75, 2233, 74, 10)
# None today * * * * * * * * * *
# (95, 3672, 152, 18)
#  QA/QC PUNCH LIST * * * * * * *
# (75, 10698, 70, 10)
# Asbestos Abatement * * * *
# (95, 7395, 112, 37)
#  ACTIVITY START/FINISH * * * * * * *
# (75, 10600, 89, 10)
#  Evergreene Construction, L.C. * * * * * *
# (82, 10286, 102, 10)
#  D/B Replace Military Family Housing P5
# (82, 159, 130, 10)
#  CONTRACT NUMBER * *
# (417, 1835, 65, 8)
#  CONTRACTOR CERTIFICATION * * * *
# (71, 8294, 98, 8)
#  No QC Punch List items were issued today * *
# (85, 3938, 165, 24)
#  Labor Classification * * *
# (197, 7394, 78, 23)
#  Activities in Progress: * * *
# (85, 5277, 86, 10)
# Shutting dow n w ater and removing refrigerators
# (95, 3604, 164, 18)
# 0.0 * * * * * * * * * * * * *
# (441, 7386, 36, 44)
#  Hours * *
# (508, 4016, 26, 20)
# No Punch List items were corrected today
# (85, 554, 164, 24)
#  Page 1 of 2 * * * *
# (494, 6849, 38, 10)
#  PREPARATORY AND/OR INITIALS HELD TODAY
# (95, 396, 427, 27)
#  DACA67-02-D-2012  0004 * * * * * * * * * *
# (424, 8579, 89, 10)
#  Activities in Progress: * * * *
# (85, 6961, 86, 10)
#  Total operating hours to date: 0.0 * * *
# (95, 6099, 112, 10)
#  No QC requirements were completed today * * * *
# (85, 7275, 169, 10)
#  CONTRACTORS FIRST AND/OR LAST DAY ONSITE * * * *
# (95, 9649, 175, 18)
# Several additional trees w ere added to the removal due to the condition of the trees - old split trunks, and poor conditions
# (95, 1921, 432, 44)
# None today * * * * * * * * *
# (95, 3646, 168, 18)
#  CONTRACTORS QUALITY CONTROL REPORT (QCR) * * * * *
# (123, 4320, 227, 12)
# 3.0
# (441, 12449, 36, 54)
# None today * * * * * * * * * * * * * * *
# (95, 5449, 163, 18)
#  CONTRACTOR CERTIFICATION * * *
# (71, 6610, 98, 8)
#  CONTRACTORS ON SITE (Report first and/or last day contractors w ere on site) * * * * * * *
# (75, 12396, 278, 10)
#  Number of * * * *
# (441, 7384, 36, 44)
#  DATE *
# (508, 1593, 16, 8)
#  No QC Punch List items were issued today * * * * * * * *
# (85, 12366, 165, 24)
# None today * *
# (95, 371, 101, 18)
#  QC REPRESENTATIVE'S SIGNATURE * * * * * * *
# (71, 11699, 115, 8)
#  CONTRACTOR CERTIFICATION * * * * * *
# (71, 9978, 98, 8)
#  No QC Punch List items were issued today * * * * * * *
# (85, 10711, 165, 24)
# Water to buildings 4204, 4210,4211 are connected to TLF units.  Must be isolated - not just turned off at unit.  Corp stop - need
# (95, 9549, 430, 27)
#  QC NARRATIVES * * * * *
# (75, 8628, 61, 10)
#  Page 1 of 2 * * * * *
# (494, 10217, 38, 10)
#  94 *
# (417, 6007, 16, 22)
#  CONTRACT NUMBER * * * * * * * * * * * * *
# (417, 11097, 65, 8)
# Should there be added costs for removal of these trees (No additional
# (95, 1922, 432, 44)
#  Labor Classification * *
# (197, 5710, 78, 23)
# 0.0 * * * * * * * * * * * * * * * * * *
# (532, 8866, 10, 20)
#  REPORT NUMBER * * * * * * * * * * * *
# (417, 10210, 56, 8)
# No Punch List items were corrected today * * * * * * * *
# (85, 12367, 165, 24)
# None * * *
# (95, 10433, 35, 18)
#  REPORT NUMBER * * * * * * *
# (417, 6000, 56, 8)
#  CONTRACT NUMBER * * * *
# (417, 3519, 65, 8)
# Employees
# (441, 632, 36, 44)
#  PREPARATORY AND/OR INITIALS HELD TODAY * * *
# (95, 5448, 163, 18)
#  (Preparatory and initial dates held and advance notice) * * * * * * *
# (170, 10569, 185, 10)
#  REPORT NUMBER * * * * * *
# (417, 5158, 56, 8)
#  Page 1 of 1 *
# (494, 9375, 38, 10)
#  CONTRACTORS QUALITY CONTROL REPORT (QCR) * * * * * * * * * * *
# (123, 9372, 227, 12)
# Weather Caused No Delay * * * *
# (319, 6911, 219, 28)
# None * *
# (95, 7065, 35, 18)
# Employees * * * * * *
# (441, 10790, 36, 34)
# Temperature Min 33 °F, Max 54 °F No Precipitation 13 MPH Wind
# (319, 6912, 219, 28)
# LABORERS *
# (197, 12455, 78, 34)
#  (Preparatory and initial dates held and advance notice) * * * * * * * *
# (170, 12261, 185, 10)
#  QC REPRESENTATIVE'S SIGNATURE * * * *
# (71, 8331, 115, 8)
#  ACTIVITY START/FINISH * *
# (75, 3864, 89, 10)
#  D/B Replace Military Family Housing P5 * * * * * * * * * *
# (82, 8579, 130, 10)
#  (Preparatory and initial dates held and advance notice) *
# (170, 2233, 185, 10)
# None today * * * * * * * * * * * * * * * * * * *
# (95, 7133, 163, 18)
